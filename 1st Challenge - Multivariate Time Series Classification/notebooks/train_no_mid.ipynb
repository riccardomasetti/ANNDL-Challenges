# %% [markdown]
# # Model trained dropping middle joints

# %%
from google.colab import drive
drive.mount('/gdrive')
current_dir = "/gdrive/My Drive/ANN-1stChallenge"

# %cd $current_dir
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1SsYTSWVYK18RYEggHgY0ijnOvaI-DARa/ANN-1stChallenge

# %%
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
# from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, DataLoader
logs_dir = "tensorboard"
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

# Set the used f1 type as macro, as using weighted benefits over-represented classes if they are very unbalanced
f1_average = 'macro'
# Out:
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %% [markdown]
# # Data loading

# %%
BASE_PATH = "datasets/"

# Load each csv
TRAIN_PATH = BASE_PATH + "pirate_pain_train.csv"
TRAIN_LABELS_PATH = BASE_PATH + "pirate_pain_train_labels.csv"
TEST_PATH = BASE_PATH + "pirate_pain_test.csv"
SUBMISSION_PATH = BASE_PATH + "sample_submission.csv"

X_train = pd.read_csv(TRAIN_PATH)
y_train = pd.read_csv(TRAIN_LABELS_PATH)

X_test = pd.read_csv(TEST_PATH)

# %%
label_encoder = LabelEncoder()

# Fit and transform the 'label' column in y_train
y_train['label_encoded'] = label_encoder.fit_transform(y_train['label'])

# Display the mapping of original labels to encoded numbers
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mapping:")
print(label_mapping)

y_train = y_train.drop('label', axis=1)
# Out:
# Label Mapping:
# {'high_pain': np.int64(0), 'low_pain': np.int64(1), 'no_pain': np.int64(2)}

# %%
# Categorical features which will be label-encoded
categorical_features = ['n_legs', 'n_hands', 'n_eyes']

encoders = {}

for col in categorical_features:
    encoders[col] = LabelEncoder() # Use same encoder for train and test

    X_train[col + '_encoded'] = encoders[col].fit_transform(X_train[col])
    X_test[col + '_encoded'] = encoders[col].transform(X_test[col])

    print(f"Label mapping for {col}: {dict(zip(encoders[col].classes_, encoders[col].transform(encoders[col].classes_)))}")

X_train = X_train.drop(categorical_features, axis=1)
X_test = X_test.drop(categorical_features, axis=1)
# Out:
# Label mapping for n_legs: {'one+peg_leg': np.int64(0), 'two': np.int64(1)}
# Label mapping for n_hands: {'one+hook_hand': np.int64(0), 'two': np.int64(1)}
# Label mapping for n_eyes: {'one+eye_patch': np.int64(0), 'two': np.int64(1)}

# %% [markdown]
# # Data preprocessing

# %%
# Merge X_train and y_train based on 'sample_index'
df = pd.merge(X_train, y_train, on='sample_index')

# %%
# Drop useless columns
columns_to_drop = [
    'time',
    'pain_survey_1',
    'pain_survey_2',
    'pain_survey_3',
    'pain_survey_4',
    'n_legs_encoded',
    'n_hands_encoded',
    'n_eyes_encoded',
    'joint_11',         # Highly correlated with joint_10
    'joint_30'          # Constant value
]

# Drop joints which have very small values, with extremely high peaks which tend to confuse the model
for i in range(13, 26):
    columns_to_drop.append(f'joint_{i}')

print(f"Columns to drop: {columns_to_drop}")
df = df.drop(columns=columns_to_drop)
X_test = X_test.drop(columns=columns_to_drop)
# Out:
# Columns to drop: ['time', 'pain_survey_1', 'pain_survey_2', 'pain_survey_3', 'pain_survey_4', 'n_legs_encoded', 'n_hands_encoded', 'n_eyes_encoded', 'joint_11', 'joint_30', 'joint_13', 'joint_14', 'joint_15', 'joint_16', 'joint_17', 'joint_18', 'joint_19', 'joint_20', 'joint_21', 'joint_22', 'joint_23', 'joint_24', 'joint_25']

# %%
# @title Train/Validation split
n_series = len(y_train)

VAL_SPLIT = 0.2 # Split used for the validation set
val_size = int(VAL_SPLIT * n_series)
train_size = n_series - val_size

sample_ids = y_train['sample_index'].unique()
random.seed(SEED)
random.shuffle(sample_ids)

train_samples = sample_ids[:train_size] # Samples used for training
val_samples = sample_ids[train_size:] # Samples used for validation

print(f"Train samples: {len(train_samples)}, validation samples: {len(val_samples)}")

df_train = df[df['sample_index'].isin(train_samples)]
df_val = df[df['sample_index'].isin(val_samples)]

print(f'Training set shape: {df_train.shape}')
print(f'Validation set shape: {df_val.shape}')
# Out:
# Train samples: 529, validation samples: 132
# Training set shape: (84640, 18)
# Validation set shape: (21120, 18)

# %%
# @title Scaling
# Scale only joints columns
scale_columns = [col for col in df_train.columns if col.startswith('joint')]

# Use minmax scaling, to keep the same shape
mins = df_train[scale_columns].min()
maxs = df_train[scale_columns].max()

for c in scale_columns:
    # Scale columns, using only train data
    df_train[c] = (df_train[c] - mins[c]) / (maxs[c] - mins[c])
    df_val[c] = (df_val[c] - mins[c]) / (maxs[c] - mins[c])
    X_test[c] = (X_test[c] - mins[c]) / (maxs[c] - mins[c])

# %%
# Define a function to build sequences from the dataset
def build_sequences(df, features, window=200, stride=200):
    # Sanity check to ensure the window is divisible by the stride
    assert window % stride == 0

    # Initialise lists to store sequences and their corresponding labels
    dataset = []
    labels = []

    # Iterate over unique IDs in the DataFrame
    for id in df['sample_index'].unique():
        # Extract sensor data for the current ID
        temp = df[df['sample_index'] == id][features].values

        # Retrieve the activity label for the current ID
        # Assuming the label column exists in the dataframe passed to the function
        label = df[df['sample_index'] == id]['label_encoded'].values[0]

        # Calculate padding length to ensure full windows
        padding_len = window - len(temp) % window

        # Create zero padding and concatenate with the data
        # The padding should have the same number of columns as the features
        padding = np.zeros((padding_len, len(features)), dtype='float64')
        temp = np.concatenate((temp, padding))

        # Build feature windows and associate them with labels
        idx = 0
        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            labels.append(label)
            idx += stride

    # Convert lists to numpy arrays for further processing
    dataset = np.array(dataset)
    labels = np.array(labels)

    return dataset, labels

# %%
# Extract input features
features = df_train.columns[1:] # Drop sample_index
features = features.drop('label_encoded')
WINDOW_SIZE = 12
STRIDE = 6

# Create train and validation sequences of window 12 and stride 6
train_x_seq, train_y_seq = build_sequences(df_train, features, window=WINDOW_SIZE, stride=STRIDE)
print(f"{len(train_x_seq)} train sequences of length {WINDOW_SIZE} and stride {STRIDE}")
val_x_seq, val_y_seq = build_sequences(df_val, features, window=WINDOW_SIZE, stride=STRIDE)
print(f"{len(val_x_seq)} validation sequences of length {WINDOW_SIZE} and stride {STRIDE}")
# Out:
# 14283 train sequences of length 12 and stride 6
# 3564 validation sequences of length 12 and stride 6

# %%
# Transform datasets to tensor datasets
train_ds = TensorDataset(torch.from_numpy(train_x_seq).float(), torch.from_numpy(train_y_seq))
val_ds = TensorDataset(torch.from_numpy(val_x_seq).float(), torch.from_numpy(val_y_seq))

# %%
def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
    )

# %%
BATCH_SIZE = 128

# Create loader for training
train_loader = make_loader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader   = make_loader(val_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %% [markdown]
# # Model architecture

# %%
class AttentionClassifier(nn.Module):
    """
    Classifier with monodirectional GRUs as encoder-decoder, using Bahdanau attention.
    """
    def __init__(
        self,
        input_size,             # Number of input features
        hidden_size,            # Hidden size of the encoder/decoder
        num_layers,             # Number of encoder/decoder layers
        num_classes,            # Number of classes
        dropout_rate=0.2        # Dropout rate
    ):
        super().__init__()

        self.num_layers = num_layers
        self.hidden_size = hidden_size

        # Encoder Layer
        self.encod_layer = nn.GRU(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=False,
            dropout=dropout_rate
        )

        encoder_output_dim = hidden_size

        # Bahdanau attention
        self.W_encoder = nn.Linear(encoder_output_dim, self.hidden_size, bias=False)
        self.W_decoder = nn.Linear(self.hidden_size, self.hidden_size, bias=False)
        self.v = nn.Parameter(torch.rand(self.hidden_size))

        # Decoder layer
        self.decod_layer = nn.GRU(
            input_size=input_size + encoder_output_dim, # Input will be original input + context vector
            hidden_size=self.hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=False,
            dropout=0 # As num_layers is 1
        )

        # It will take the final hidden state of the decoder, which has size self.hidden_size
        self.classifier = nn.Linear(self.hidden_size, num_classes)


    def attention(self, encoder_outputs, decoder_hidden_state):
        # encoder_outputs: (batch_size, seq_len, encoder_output_dim)
        # decoder_hidden_state: (1, batch_size, decoder_hidden_size) -> (batch_size, decoder_hidden_size)

        # Project encoder outputs and decoder hidden state
        # (batch_size, seq_len, hidden_size)
        e_proj = self.W_encoder(encoder_outputs)
        # (batch_size, hidden_size)
        d_proj = self.W_decoder(decoder_hidden_state.squeeze(0))

        # Expand d_proj to (batch_size, seq_len, hidden_size) for element-wise addition
        d_proj = d_proj.unsqueeze(1).expand_as(e_proj)

        # Energy: tanh(W_e*E + W_d*D)
        # (batch_size, seq_len, hidden_size)
        energy = torch.tanh(e_proj + d_proj)

        # Attention scores: v^T * energy
        # v: (hidden_size)
        # energy: (batch_size, seq_len, hidden_size)
        # (batch_size, seq_len)
        # The original code has an error in how it performs the batch matrix multiplication with self.v.
        # It should be `torch.einsum('bsd,d->bs', energy, self.v)` or a proper bmm with reshaped v.
        # Let's fix it to a more standard and correct way: multiplying energy with v (which is broadcasted)
        # and summing over the last dimension.
        attention_scores = torch.sum(self.v * energy, dim=2)

        # Softmax to get attention weights
        # (batch_size, seq_len)
        attention_weights = torch.softmax(attention_scores, dim=1)

        # Context vector: weighted sum of encoder outputs
        # (batch_size, 1, seq_len) @ (batch_size, seq_len, encoder_output_dim) -> (batch_size, 1, encoder_output_dim)
        context_vector = torch.bmm(attention_weights.unsqueeze(1), encoder_outputs).squeeze(1)

        return context_vector


    def forward(self, x):
        # x shape: (batch_size, seq_length, input_size)

        # Encoder pass
        encoder_outputs, encoder_hidden = self.encod_layer(x)

        decoder_initial_hidden = encoder_hidden[-1].unsqueeze(0) # (1, batch_size, hidden_size)

        # Prepare for decoder steps
        current_decoder_hidden = decoder_initial_hidden

        # Iterate through sequence length for decoding steps
        for i in range(x.size(1)): # x.size(1) is the sequence length
            # Current input for decoder step
            decoder_input_step = x[:, i, :].unsqueeze(1) # (batch_size, 1, input_size)

            # Compute context vector using attention
            context_vector = self.attention(encoder_outputs, current_decoder_hidden) # (batch_size, encoder_output_dim)

            # Concatenate decoder input with context vector
            # (batch_size, 1, input_size + encoder_output_dim)
            decoder_input_with_context = torch.cat(
                (decoder_input_step, context_vector.unsqueeze(1)), dim=2
            )

            # Decoder GRU step
            # current_decoder_hidden is (1, batch_size, hidden_size)
            _, current_decoder_hidden = self.decod_layer(
                decoder_input_with_context, current_decoder_hidden
            )

        # The final hidden state of the decoder after processing all steps is used for classification
        # current_decoder_hidden is (1, batch_size, hidden_size)
        # Squeeze to (batch_size, hidden_size) for the linear classifier
        logits = self.classifier(current_decoder_hidden.squeeze(0))
        return logits

# %% [markdown]
# # Train functions

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average=f1_average
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average=f1_average
    )

    return epoch_loss, epoch_accuracy

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):
    """
    Log training metrics and model parameters to TensorBoard for visualization.

    Args:
        writer (SummaryWriter): TensorBoard SummaryWriter object for logging
        epoch (int): Current epoch number (used as x-axis in TensorBoard plots)
        train_loss (float): Training loss for this epoch
        train_f1 (float): Training f1 score for this epoch
        val_loss (float): Validation loss for this epoch
        val_f1 (float): Validation f1 score for this epoch
        model (nn.Module): The neural network model (for logging weights/gradients)

    Note:
        This function logs scalar metrics (loss/f1 score) and histograms of model
        parameters and gradients, which helps monitor training progress and detect
        issues like vanishing/exploding gradients.
    """
    # Log scalar metrics
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    # Log model parameters and gradients
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Check if the tensor is not empty before adding a histogram
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None:
                # Check if the gradient tensor is not empty before adding a histogram
                if param.grad.numel() > 0:
                    if param.grad is not None and torch.isfinite(param.grad).all():
                        writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name="", scheduler=None):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Step the scheduler if provided (typically after validation)
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                # For ReduceLROnPlateau with mode='min', step with validation loss
                scheduler.step(val_loss)
            else:
                scheduler.step()

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        if writer is not None:
            log_metrics_to_tensorboard(
                writer, epoch, train_loss, train_f1, val_loss, val_f1, model
            )

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load("models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# # Model training

# %%
# Training configuration
LEARNING_RATE = 1e-3
EPOCHS = 2000
PATIENCE = 500

# Architecture
HIDDEN_LAYERS = 1        # Hidden layers
HIDDEN_SIZE = 128        # Neurons per layer

# Regularisation
DROPOUT_RATE = 0.5         # Dropout probability
L1_LAMBDA = 1e-4            # L1 penalty
L2_LAMBDA = 1e-4         # L2 penalty

# Set up loss function and optimizer
criterion = nn.CrossEntropyLoss()

input_shape = train_x_seq.shape[1:]

# Create model and display architecture with parameter count
model = AttentionClassifier(
    input_size=input_shape[-1], # Pass the number of features
    hidden_size=HIDDEN_SIZE,
    num_layers=HIDDEN_LAYERS,
    num_classes=3,
    dropout_rate=DROPOUT_RATE,
).to(device)

# Set up TensorBoard logging and save model architecture
experiment_name = "final_nomid_2"
writer = SummaryWriter("./"+logs_dir+"/"+experiment_name)
x = torch.randn(1, input_shape[0], input_shape[1]).to(device)
writer.add_graph(model, x)

# Define optimizer with L2 regularization
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=L2_LAMBDA)

# Enable mixed precision training for GPU acceleration
scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

# %%
# @title Train
# %%time

# Train model and track training history
model, training_history = fit(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    l1_lambda=L1_LAMBDA,
    l2_lambda=L2_LAMBDA,
    scaler=scaler,
    device=device,
    writer=writer,
    verbose=1,
    experiment_name=experiment_name,
    patience=PATIENCE,
    scheduler=None
)
# Out:
# Training 2000 epochs...
# Epoch   1/2000 | Train: Loss=1.0774, F1 Score=0.3326 | Val: Loss=0.6354, F1 Score=0.3605
# Epoch   2/2000 | Train: Loss=0.7150, F1 Score=0.4066 | Val: Loss=0.6182, F1 Score=0.3900
# Epoch   3/2000 | Train: Loss=0.6606, F1 Score=0.4508 | Val: Loss=0.6025, F1 Score=0.4267
# Epoch   4/2000 | Train: Loss=0.6339, F1 Score=0.4819 | Val: Loss=0.5937, F1 Score=0.5272
# Epoch   5/2000 | Train: Loss=0.6147, F1 Score=0.5194 | Val: Loss=0.5834, F1 Score=0.4436
# Epoch   6/2000 | Train: Loss=0.5898, F1 Score=0.5462 | Val: Loss=0.5973, F1 Score=0.4917
# Epoch   7/2000 | Train: Loss=0.5357, F1 Score=0.6041 | Val: Loss=0.5343, F1 Score=0.5759
# Epoch   8/2000 | Train: Loss=0.4621, F1 Score=0.6747 | Val: Loss=0.5135, F1 Score=0.6505
# Epoch   9/2000 | Train: Loss=0.4413, F1 Score=0.6983 | Val: Loss=0.4973, F1 Score=0.6504
# Epoch  10/2000 | Train: Loss=0.4207, F1 Score=0.7093 | Val: Loss=0.5112, F1 Score=0.6072
# Epoch  11/2000 | Train: Loss=0.4043, F1 Score=0.7252 | Val: Loss=0.4776, F1 Score=0.6399
# Epoch  12/2000 | Train: Loss=0.3832, F1 Score=0.7379 | Val: Loss=0.4269, F1 Score=0.6853
# Epoch  13/2000 | Train: Loss=0.3677, F1 Score=0.7511 | Val: Loss=0.4186, F1 Score=0.6918
# Epoch  14/2000 | Train: Loss=0.3564, F1 Score=0.7550 | Val: Loss=0.4278, F1 Score=0.6909
# Epoch  15/2000 | Train: Loss=0.3478, F1 Score=0.7667 | Val: Loss=0.4490, F1 Score=0.6596
# Epoch  16/2000 | Train: Loss=0.3421, F1 Score=0.7642 | Val: Loss=0.4261, F1 Score=0.6757
# Epoch  17/2000 | Train: Loss=0.3308, F1 Score=0.7764 | Val: Loss=0.4659, F1 Score=0.6683
# Epoch  18/2000 | Train: Loss=0.3322, F1 Score=0.7696 | Val: Loss=0.4388, F1 Score=0.6776
# Epoch  19/2000 | Train: Loss=0.3217, F1 Score=0.7781 | Val: Loss=0.4257, F1 Score=0.6729
# Epoch  20/2000 | Train: Loss=0.3167, F1 Score=0.7822 | Val: Loss=0.4248, F1 Score=0.6870
# Epoch  21/2000 | Train: Loss=0.3176, F1 Score=0.7718 | Val: Loss=0.4149, F1 Score=0.6874
# Epoch  22/2000 | Train: Loss=0.3015, F1 Score=0.7923 | Val: Loss=0.4065, F1 Score=0.6864
# Epoch  23/2000 | Train: Loss=0.2985, F1 Score=0.7954 | Val: Loss=0.4236, F1 Score=0.6899
# Epoch  24/2000 | Train: Loss=0.2950, F1 Score=0.8132 | Val: Loss=0.3905, F1 Score=0.7256
# Epoch  25/2000 | Train: Loss=0.2721, F1 Score=0.8326 | Val: Loss=0.4534, F1 Score=0.7205
# Epoch  26/2000 | Train: Loss=0.2720, F1 Score=0.8316 | Val: Loss=0.5055, F1 Score=0.6846
# Epoch  27/2000 | Train: Loss=0.2722, F1 Score=0.8310 | Val: Loss=0.4105, F1 Score=0.7393
# Epoch  28/2000 | Train: Loss=0.2568, F1 Score=0.8417 | Val: Loss=0.4110, F1 Score=0.7401
# Epoch  29/2000 | Train: Loss=0.2600, F1 Score=0.8442 | Val: Loss=0.3950, F1 Score=0.7332
# Epoch  30/2000 | Train: Loss=0.2552, F1 Score=0.8438 | Val: Loss=0.4130, F1 Score=0.7561
# Epoch  31/2000 | Train: Loss=0.2513, F1 Score=0.8500 | Val: Loss=0.4295, F1 Score=0.7298
# Epoch  32/2000 | Train: Loss=0.2454, F1 Score=0.8527 | Val: Loss=0.4103, F1 Score=0.7409
# Epoch  33/2000 | Train: Loss=0.2552, F1 Score=0.8434 | Val: Loss=0.4142, F1 Score=0.7473
# Epoch  34/2000 | Train: Loss=0.2430, F1 Score=0.8540 | Val: Loss=0.3865, F1 Score=0.7539
# Epoch  35/2000 | Train: Loss=0.2384, F1 Score=0.8576 | Val: Loss=0.4117, F1 Score=0.7581
# Epoch  36/2000 | Train: Loss=0.2410, F1 Score=0.8597 | Val: Loss=0.4161, F1 Score=0.7290
# Epoch  37/2000 | Train: Loss=0.2450, F1 Score=0.8528 | Val: Loss=0.3933, F1 Score=0.7571
# Epoch  38/2000 | Train: Loss=0.2400, F1 Score=0.8594 | Val: Loss=0.4240, F1 Score=0.7427
# Epoch  39/2000 | Train: Loss=0.2315, F1 Score=0.8630 | Val: Loss=0.3873, F1 Score=0.7526
# Epoch  40/2000 | Train: Loss=0.2366, F1 Score=0.8607 | Val: Loss=0.4016, F1 Score=0.7627
# Epoch  41/2000 | Train: Loss=0.2282, F1 Score=0.8653 | Val: Loss=0.3993, F1 Score=0.7564
# Epoch  42/2000 | Train: Loss=0.2326, F1 Score=0.8668 | Val: Loss=0.5005, F1 Score=0.7225
# Epoch  43/2000 | Train: Loss=0.2237, F1 Score=0.8696 | Val: Loss=0.4004, F1 Score=0.7600
# Epoch  44/2000 | Train: Loss=0.2191, F1 Score=0.8728 | Val: Loss=0.4141, F1 Score=0.7498
# Epoch  45/2000 | Train: Loss=0.2235, F1 Score=0.8715 | Val: Loss=0.4168, F1 Score=0.7600
# Epoch  46/2000 | Train: Loss=0.2156, F1 Score=0.8768 | Val: Loss=0.4283, F1 Score=0.7550
# Epoch  47/2000 | Train: Loss=0.2131, F1 Score=0.8809 | Val: Loss=0.4367, F1 Score=0.7334
# Epoch  48/2000 | Train: Loss=0.2203, F1 Score=0.8725 | Val: Loss=0.4307, F1 Score=0.7607
# Epoch  49/2000 | Train: Loss=0.2166, F1 Score=0.8785 | Val: Loss=0.4042, F1 Score=0.7634
# Epoch  50/2000 | Train: Loss=0.2158, F1 Score=0.8740 | Val: Loss=0.4142, F1 Score=0.7353
# Epoch  51/2000 | Train: Loss=0.2179, F1 Score=0.8764 | Val: Loss=0.4800, F1 Score=0.7337
# Epoch  52/2000 | Train: Loss=0.2174, F1 Score=0.8773 | Val: Loss=0.4317, F1 Score=0.7465
# Epoch  53/2000 | Train: Loss=0.2145, F1 Score=0.8782 | Val: Loss=0.4136, F1 Score=0.7505
# Epoch  54/2000 | Train: Loss=0.2122, F1 Score=0.8816 | Val: Loss=0.5389, F1 Score=0.7254
# Epoch  55/2000 | Train: Loss=0.2115, F1 Score=0.8855 | Val: Loss=0.4902, F1 Score=0.7544
# Epoch  56/2000 | Train: Loss=0.2083, F1 Score=0.8865 | Val: Loss=0.4109, F1 Score=0.7561
# Epoch  57/2000 | Train: Loss=0.2021, F1 Score=0.8925 | Val: Loss=0.4498, F1 Score=0.7541
# Epoch  58/2000 | Train: Loss=0.2046, F1 Score=0.8879 | Val: Loss=0.4621, F1 Score=0.7538
# Epoch  59/2000 | Train: Loss=0.2057, F1 Score=0.8864 | Val: Loss=0.4993, F1 Score=0.7189
# Epoch  60/2000 | Train: Loss=0.2049, F1 Score=0.8887 | Val: Loss=0.4765, F1 Score=0.7281
# Epoch  61/2000 | Train: Loss=0.2069, F1 Score=0.8901 | Val: Loss=0.4697, F1 Score=0.7427
# Epoch  62/2000 | Train: Loss=0.2064, F1 Score=0.8879 | Val: Loss=0.4402, F1 Score=0.7570
# Epoch  63/2000 | Train: Loss=0.1987, F1 Score=0.8932 | Val: Loss=0.4810, F1 Score=0.7389
# Epoch  64/2000 | Train: Loss=0.2030, F1 Score=0.8873 | Val: Loss=0.4636, F1 Score=0.7488
# Epoch  65/2000 | Train: Loss=0.1947, F1 Score=0.8993 | Val: Loss=0.5411, F1 Score=0.7391
# Epoch  66/2000 | Train: Loss=0.2048, F1 Score=0.8906 | Val: Loss=0.4323, F1 Score=0.7474
# Epoch  67/2000 | Train: Loss=0.1978, F1 Score=0.8992 | Val: Loss=0.5318, F1 Score=0.7350
# Epoch  68/2000 | Train: Loss=0.1958, F1 Score=0.8979 | Val: Loss=0.5027, F1 Score=0.7370
# Epoch  69/2000 | Train: Loss=0.1970, F1 Score=0.9015 | Val: Loss=0.4906, F1 Score=0.7437
# Epoch  70/2000 | Train: Loss=0.1971, F1 Score=0.8973 | Val: Loss=0.4331, F1 Score=0.7474
# Epoch  71/2000 | Train: Loss=0.1895, F1 Score=0.9049 | Val: Loss=0.4705, F1 Score=0.7416
# Epoch  72/2000 | Train: Loss=0.1887, F1 Score=0.9053 | Val: Loss=0.4646, F1 Score=0.7496
# Epoch  73/2000 | Train: Loss=0.1916, F1 Score=0.9028 | Val: Loss=0.4344, F1 Score=0.7634
# Epoch  74/2000 | Train: Loss=0.1981, F1 Score=0.9031 | Val: Loss=0.4759, F1 Score=0.7420
# Epoch  75/2000 | Train: Loss=0.1909, F1 Score=0.9042 | Val: Loss=0.4154, F1 Score=0.7706
# Epoch  76/2000 | Train: Loss=0.1876, F1 Score=0.9066 | Val: Loss=0.4116, F1 Score=0.7645
# Epoch  77/2000 | Train: Loss=0.1874, F1 Score=0.9072 | Val: Loss=0.5077, F1 Score=0.7290
# Epoch  78/2000 | Train: Loss=0.1868, F1 Score=0.9111 | Val: Loss=0.4997, F1 Score=0.7401
# Epoch  79/2000 | Train: Loss=0.1996, F1 Score=0.9001 | Val: Loss=0.4607, F1 Score=0.7596
# Epoch  80/2000 | Train: Loss=0.1782, F1 Score=0.9163 | Val: Loss=0.5349, F1 Score=0.7479
# Epoch  81/2000 | Train: Loss=0.1768, F1 Score=0.9174 | Val: Loss=0.4905, F1 Score=0.7433
# Epoch  82/2000 | Train: Loss=0.1835, F1 Score=0.9125 | Val: Loss=0.4626, F1 Score=0.7448
# Epoch  83/2000 | Train: Loss=0.1838, F1 Score=0.9063 | Val: Loss=0.4930, F1 Score=0.7396
# Epoch  84/2000 | Train: Loss=0.1780, F1 Score=0.9187 | Val: Loss=0.5336, F1 Score=0.7505
# Epoch  85/2000 | Train: Loss=0.1903, F1 Score=0.9071 | Val: Loss=0.4294, F1 Score=0.7591
# Epoch  86/2000 | Train: Loss=0.1763, F1 Score=0.9204 | Val: Loss=0.5748, F1 Score=0.7231
# Epoch  87/2000 | Train: Loss=0.1833, F1 Score=0.9126 | Val: Loss=0.4380, F1 Score=0.7499
# Epoch  88/2000 | Train: Loss=0.1758, F1 Score=0.9175 | Val: Loss=0.4559, F1 Score=0.7590
# Epoch  89/2000 | Train: Loss=0.1691, F1 Score=0.9224 | Val: Loss=0.5270, F1 Score=0.7373
# Epoch  90/2000 | Train: Loss=0.1802, F1 Score=0.9138 | Val: Loss=0.5053, F1 Score=0.7474
# Epoch  91/2000 | Train: Loss=0.1782, F1 Score=0.9188 | Val: Loss=0.4416, F1 Score=0.7803
# Epoch  92/2000 | Train: Loss=0.1740, F1 Score=0.9229 | Val: Loss=0.4603, F1 Score=0.7547
# Epoch  93/2000 | Train: Loss=0.1688, F1 Score=0.9236 | Val: Loss=0.4453, F1 Score=0.7670
# Epoch  94/2000 | Train: Loss=0.1810, F1 Score=0.9167 | Val: Loss=0.4202, F1 Score=0.7730
# Epoch  95/2000 | Train: Loss=0.1769, F1 Score=0.9196 | Val: Loss=0.4456, F1 Score=0.7618
# Epoch  96/2000 | Train: Loss=0.1647, F1 Score=0.9293 | Val: Loss=0.4687, F1 Score=0.7610
# Epoch  97/2000 | Train: Loss=0.1722, F1 Score=0.9212 | Val: Loss=0.4759, F1 Score=0.7431
# Epoch  98/2000 | Train: Loss=0.1648, F1 Score=0.9304 | Val: Loss=0.4800, F1 Score=0.7702
# Epoch  99/2000 | Train: Loss=0.1653, F1 Score=0.9296 | Val: Loss=0.4880, F1 Score=0.7618
# Epoch 100/2000 | Train: Loss=0.1596, F1 Score=0.9312 | Val: Loss=0.5728, F1 Score=0.7322
# Epoch 101/2000 | Train: Loss=0.1712, F1 Score=0.9285 | Val: Loss=0.4989, F1 Score=0.7642
# Epoch 102/2000 | Train: Loss=0.1626, F1 Score=0.9321 | Val: Loss=0.4300, F1 Score=0.7869
# Epoch 103/2000 | Train: Loss=0.1603, F1 Score=0.9327 | Val: Loss=0.5170, F1 Score=0.7398
# Epoch 104/2000 | Train: Loss=0.1625, F1 Score=0.9357 | Val: Loss=0.4906, F1 Score=0.7724
# Epoch 105/2000 | Train: Loss=0.1655, F1 Score=0.9288 | Val: Loss=0.4999, F1 Score=0.7611
# Epoch 106/2000 | Train: Loss=0.1722, F1 Score=0.9244 | Val: Loss=0.4216, F1 Score=0.7974
# Epoch 107/2000 | Train: Loss=0.1558, F1 Score=0.9359 | Val: Loss=0.4026, F1 Score=0.7839
# Epoch 108/2000 | Train: Loss=0.1639, F1 Score=0.9279 | Val: Loss=0.4342, F1 Score=0.7687
# Epoch 109/2000 | Train: Loss=0.1529, F1 Score=0.9367 | Val: Loss=0.4306, F1 Score=0.8032
# Epoch 110/2000 | Train: Loss=0.1545, F1 Score=0.9328 | Val: Loss=0.4581, F1 Score=0.7825
# Epoch 111/2000 | Train: Loss=0.1476, F1 Score=0.9390 | Val: Loss=0.4168, F1 Score=0.7976
# Epoch 112/2000 | Train: Loss=0.1519, F1 Score=0.9400 | Val: Loss=0.4812, F1 Score=0.7621
# Epoch 113/2000 | Train: Loss=0.1486, F1 Score=0.9393 | Val: Loss=0.4382, F1 Score=0.7750
# Epoch 114/2000 | Train: Loss=0.1507, F1 Score=0.9398 | Val: Loss=0.4475, F1 Score=0.7872
# Epoch 115/2000 | Train: Loss=0.1598, F1 Score=0.9343 | Val: Loss=0.4118, F1 Score=0.7861
# Epoch 116/2000 | Train: Loss=0.1542, F1 Score=0.9404 | Val: Loss=0.5339, F1 Score=0.7587
# Epoch 117/2000 | Train: Loss=0.1462, F1 Score=0.9423 | Val: Loss=0.4339, F1 Score=0.7765
# Epoch 118/2000 | Train: Loss=0.1479, F1 Score=0.9410 | Val: Loss=0.5333, F1 Score=0.7699
# Epoch 119/2000 | Train: Loss=0.1471, F1 Score=0.9421 | Val: Loss=0.4978, F1 Score=0.7548
# Epoch 120/2000 | Train: Loss=0.1508, F1 Score=0.9377 | Val: Loss=0.4077, F1 Score=0.7826
# Epoch 121/2000 | Train: Loss=0.1574, F1 Score=0.9366 | Val: Loss=0.3666, F1 Score=0.8110
# Epoch 122/2000 | Train: Loss=0.1484, F1 Score=0.9448 | Val: Loss=0.4528, F1 Score=0.7936
# Epoch 123/2000 | Train: Loss=0.1484, F1 Score=0.9429 | Val: Loss=0.4320, F1 Score=0.7917
# Epoch 124/2000 | Train: Loss=0.1437, F1 Score=0.9434 | Val: Loss=0.4568, F1 Score=0.8007
# Epoch 125/2000 | Train: Loss=0.1414, F1 Score=0.9470 | Val: Loss=0.4261, F1 Score=0.7946
# Epoch 126/2000 | Train: Loss=0.1436, F1 Score=0.9432 | Val: Loss=0.4914, F1 Score=0.7815
# Epoch 127/2000 | Train: Loss=0.1463, F1 Score=0.9454 | Val: Loss=0.4648, F1 Score=0.7383
# Epoch 128/2000 | Train: Loss=0.1398, F1 Score=0.9483 | Val: Loss=0.4338, F1 Score=0.7839
# Epoch 129/2000 | Train: Loss=0.1397, F1 Score=0.9487 | Val: Loss=0.5792, F1 Score=0.7317
# Epoch 130/2000 | Train: Loss=0.1392, F1 Score=0.9483 | Val: Loss=0.4596, F1 Score=0.7879
# Epoch 131/2000 | Train: Loss=0.1421, F1 Score=0.9447 | Val: Loss=0.4047, F1 Score=0.7853
# Epoch 132/2000 | Train: Loss=0.1378, F1 Score=0.9486 | Val: Loss=0.4251, F1 Score=0.7747
# Epoch 133/2000 | Train: Loss=0.1337, F1 Score=0.9511 | Val: Loss=0.4785, F1 Score=0.7782
# Epoch 134/2000 | Train: Loss=0.1461, F1 Score=0.9444 | Val: Loss=0.3794, F1 Score=0.8055
# Epoch 135/2000 | Train: Loss=0.1511, F1 Score=0.9447 | Val: Loss=0.4612, F1 Score=0.7785
# Epoch 136/2000 | Train: Loss=0.1350, F1 Score=0.9509 | Val: Loss=0.4380, F1 Score=0.7947
# Epoch 137/2000 | Train: Loss=0.1347, F1 Score=0.9547 | Val: Loss=0.3936, F1 Score=0.7987
# Epoch 138/2000 | Train: Loss=0.1421, F1 Score=0.9446 | Val: Loss=0.4284, F1 Score=0.7845
# Epoch 139/2000 | Train: Loss=0.1338, F1 Score=0.9520 | Val: Loss=0.4840, F1 Score=0.7646
# Epoch 140/2000 | Train: Loss=0.1334, F1 Score=0.9523 | Val: Loss=0.4241, F1 Score=0.7938
# Epoch 141/2000 | Train: Loss=0.1354, F1 Score=0.9522 | Val: Loss=0.4059, F1 Score=0.7975
# Epoch 142/2000 | Train: Loss=0.1355, F1 Score=0.9507 | Val: Loss=0.4980, F1 Score=0.7863
# Epoch 143/2000 | Train: Loss=0.1402, F1 Score=0.9469 | Val: Loss=0.4065, F1 Score=0.7975
# Epoch 144/2000 | Train: Loss=0.1377, F1 Score=0.9469 | Val: Loss=0.4436, F1 Score=0.7732
# Epoch 145/2000 | Train: Loss=0.1336, F1 Score=0.9518 | Val: Loss=0.3654, F1 Score=0.8053
# Epoch 146/2000 | Train: Loss=0.1282, F1 Score=0.9556 | Val: Loss=0.4742, F1 Score=0.7755
# Epoch 147/2000 | Train: Loss=0.1345, F1 Score=0.9499 | Val: Loss=0.4749, F1 Score=0.7627
# Epoch 148/2000 | Train: Loss=0.1282, F1 Score=0.9571 | Val: Loss=0.3967, F1 Score=0.8141
# Epoch 149/2000 | Train: Loss=0.1290, F1 Score=0.9557 | Val: Loss=0.4076, F1 Score=0.8063
# Epoch 150/2000 | Train: Loss=0.1400, F1 Score=0.9505 | Val: Loss=0.4341, F1 Score=0.7891
# Epoch 151/2000 | Train: Loss=0.1289, F1 Score=0.9559 | Val: Loss=0.4458, F1 Score=0.7880
# Epoch 152/2000 | Train: Loss=0.1265, F1 Score=0.9579 | Val: Loss=0.3822, F1 Score=0.8034
# Epoch 153/2000 | Train: Loss=0.1299, F1 Score=0.9561 | Val: Loss=0.3624, F1 Score=0.8144
# Epoch 154/2000 | Train: Loss=0.1292, F1 Score=0.9548 | Val: Loss=0.3287, F1 Score=0.8314
# Epoch 155/2000 | Train: Loss=0.1288, F1 Score=0.9581 | Val: Loss=0.3963, F1 Score=0.8050
# Epoch 156/2000 | Train: Loss=0.1316, F1 Score=0.9500 | Val: Loss=0.4180, F1 Score=0.7802
# Epoch 157/2000 | Train: Loss=0.1256, F1 Score=0.9546 | Val: Loss=0.4401, F1 Score=0.8035
# Epoch 158/2000 | Train: Loss=0.1206, F1 Score=0.9623 | Val: Loss=0.4362, F1 Score=0.8016
# Epoch 159/2000 | Train: Loss=0.1280, F1 Score=0.9564 | Val: Loss=0.4422, F1 Score=0.7820
# Epoch 160/2000 | Train: Loss=0.1244, F1 Score=0.9590 | Val: Loss=0.4516, F1 Score=0.7863
# Epoch 161/2000 | Train: Loss=0.1260, F1 Score=0.9596 | Val: Loss=0.3849, F1 Score=0.8084
# Epoch 162/2000 | Train: Loss=0.1212, F1 Score=0.9594 | Val: Loss=0.4449, F1 Score=0.7859
# Epoch 163/2000 | Train: Loss=0.1292, F1 Score=0.9524 | Val: Loss=0.3936, F1 Score=0.7954
# Epoch 164/2000 | Train: Loss=0.1359, F1 Score=0.9511 | Val: Loss=0.4030, F1 Score=0.7936
# Epoch 165/2000 | Train: Loss=0.1247, F1 Score=0.9589 | Val: Loss=0.3970, F1 Score=0.7947
# Epoch 166/2000 | Train: Loss=0.1290, F1 Score=0.9562 | Val: Loss=0.4104, F1 Score=0.7811
# Epoch 167/2000 | Train: Loss=0.1257, F1 Score=0.9584 | Val: Loss=0.4309, F1 Score=0.7883
# Epoch 168/2000 | Train: Loss=0.1271, F1 Score=0.9583 | Val: Loss=0.4432, F1 Score=0.7897
# Epoch 169/2000 | Train: Loss=0.1244, F1 Score=0.9563 | Val: Loss=0.4487, F1 Score=0.7780
# Epoch 170/2000 | Train: Loss=0.1215, F1 Score=0.9606 | Val: Loss=0.4155, F1 Score=0.8057
# Epoch 171/2000 | Train: Loss=0.1169, F1 Score=0.9621 | Val: Loss=0.3473, F1 Score=0.8235
# Epoch 172/2000 | Train: Loss=0.1282, F1 Score=0.9570 | Val: Loss=0.3694, F1 Score=0.8214
# Epoch 173/2000 | Train: Loss=0.1300, F1 Score=0.9558 | Val: Loss=0.4252, F1 Score=0.7874
# Epoch 174/2000 | Train: Loss=0.1222, F1 Score=0.9607 | Val: Loss=0.4750, F1 Score=0.7841
# Epoch 175/2000 | Train: Loss=0.1213, F1 Score=0.9604 | Val: Loss=0.3774, F1 Score=0.8064
# Epoch 176/2000 | Train: Loss=0.1209, F1 Score=0.9614 | Val: Loss=0.3785, F1 Score=0.8080
# Epoch 177/2000 | Train: Loss=0.1186, F1 Score=0.9623 | Val: Loss=0.3834, F1 Score=0.8096
# Epoch 178/2000 | Train: Loss=0.1227, F1 Score=0.9581 | Val: Loss=0.4378, F1 Score=0.8020
# Epoch 179/2000 | Train: Loss=0.1217, F1 Score=0.9583 | Val: Loss=0.3710, F1 Score=0.8231
# Epoch 180/2000 | Train: Loss=0.1206, F1 Score=0.9613 | Val: Loss=0.4218, F1 Score=0.8100
# Epoch 181/2000 | Train: Loss=0.1181, F1 Score=0.9628 | Val: Loss=0.4619, F1 Score=0.7746
# Epoch 182/2000 | Train: Loss=0.1190, F1 Score=0.9632 | Val: Loss=0.3869, F1 Score=0.8193
# Epoch 183/2000 | Train: Loss=0.1218, F1 Score=0.9590 | Val: Loss=0.4456, F1 Score=0.7635
# Epoch 184/2000 | Train: Loss=0.1156, F1 Score=0.9628 | Val: Loss=0.4224, F1 Score=0.7971
# Epoch 185/2000 | Train: Loss=0.1157, F1 Score=0.9635 | Val: Loss=0.4330, F1 Score=0.7805
# Epoch 186/2000 | Train: Loss=0.1211, F1 Score=0.9590 | Val: Loss=0.4556, F1 Score=0.7848
# Epoch 187/2000 | Train: Loss=0.1174, F1 Score=0.9636 | Val: Loss=0.4454, F1 Score=0.7816
# Epoch 188/2000 | Train: Loss=0.1170, F1 Score=0.9628 | Val: Loss=0.5328, F1 Score=0.7473
# Epoch 189/2000 | Train: Loss=0.1170, F1 Score=0.9630 | Val: Loss=0.4384, F1 Score=0.7776
# Epoch 190/2000 | Train: Loss=0.1278, F1 Score=0.9558 | Val: Loss=0.4203, F1 Score=0.7868
# Epoch 191/2000 | Train: Loss=0.1177, F1 Score=0.9619 | Val: Loss=0.3958, F1 Score=0.7812
# Epoch 192/2000 | Train: Loss=0.1247, F1 Score=0.9570 | Val: Loss=0.4160, F1 Score=0.7969
# Epoch 193/2000 | Train: Loss=0.1160, F1 Score=0.9606 | Val: Loss=0.3356, F1 Score=0.8276
# Epoch 194/2000 | Train: Loss=0.1130, F1 Score=0.9624 | Val: Loss=0.4622, F1 Score=0.8053
# Epoch 195/2000 | Train: Loss=0.1134, F1 Score=0.9658 | Val: Loss=0.3995, F1 Score=0.7935
# Epoch 196/2000 | Train: Loss=0.1146, F1 Score=0.9643 | Val: Loss=0.4532, F1 Score=0.7944
# Epoch 197/2000 | Train: Loss=0.1152, F1 Score=0.9628 | Val: Loss=0.3522, F1 Score=0.8284
# Epoch 198/2000 | Train: Loss=0.1133, F1 Score=0.9629 | Val: Loss=0.4431, F1 Score=0.8008
# Epoch 199/2000 | Train: Loss=0.1152, F1 Score=0.9618 | Val: Loss=0.4169, F1 Score=0.8057
# Epoch 200/2000 | Train: Loss=0.1213, F1 Score=0.9579 | Val: Loss=0.4814, F1 Score=0.7944
# Epoch 201/2000 | Train: Loss=0.1140, F1 Score=0.9662 | Val: Loss=0.4200, F1 Score=0.8102
# Epoch 202/2000 | Train: Loss=0.1120, F1 Score=0.9667 | Val: Loss=0.4438, F1 Score=0.8019
# Epoch 203/2000 | Train: Loss=0.1214, F1 Score=0.9599 | Val: Loss=0.3757, F1 Score=0.8143
# Epoch 204/2000 | Train: Loss=0.1166, F1 Score=0.9608 | Val: Loss=0.4271, F1 Score=0.7857
# Epoch 205/2000 | Train: Loss=0.1172, F1 Score=0.9609 | Val: Loss=0.3823, F1 Score=0.8124
# Epoch 206/2000 | Train: Loss=0.1231, F1 Score=0.9556 | Val: Loss=0.4359, F1 Score=0.7925
# Epoch 207/2000 | Train: Loss=0.1090, F1 Score=0.9681 | Val: Loss=0.4290, F1 Score=0.7979
# Epoch 208/2000 | Train: Loss=0.1186, F1 Score=0.9611 | Val: Loss=0.4777, F1 Score=0.7737
# Epoch 209/2000 | Train: Loss=0.1208, F1 Score=0.9639 | Val: Loss=0.3706, F1 Score=0.8173
# Epoch 210/2000 | Train: Loss=0.1124, F1 Score=0.9671 | Val: Loss=0.4388, F1 Score=0.7929
# Epoch 211/2000 | Train: Loss=0.1097, F1 Score=0.9663 | Val: Loss=0.4590, F1 Score=0.7857
# Epoch 212/2000 | Train: Loss=0.1070, F1 Score=0.9648 | Val: Loss=0.4620, F1 Score=0.7952
# Epoch 213/2000 | Train: Loss=0.1112, F1 Score=0.9650 | Val: Loss=0.4370, F1 Score=0.7978
# Epoch 214/2000 | Train: Loss=0.1113, F1 Score=0.9663 | Val: Loss=0.3941, F1 Score=0.8170
# Epoch 215/2000 | Train: Loss=0.1079, F1 Score=0.9680 | Val: Loss=0.4338, F1 Score=0.8152
# Epoch 216/2000 | Train: Loss=0.1080, F1 Score=0.9680 | Val: Loss=0.3687, F1 Score=0.8178
# Epoch 217/2000 | Train: Loss=0.1139, F1 Score=0.9641 | Val: Loss=0.4301, F1 Score=0.8017
# Epoch 218/2000 | Train: Loss=0.1110, F1 Score=0.9644 | Val: Loss=0.3324, F1 Score=0.8406
# Epoch 219/2000 | Train: Loss=0.1082, F1 Score=0.9670 | Val: Loss=0.4154, F1 Score=0.8050
# Epoch 220/2000 | Train: Loss=0.1056, F1 Score=0.9704 | Val: Loss=0.4627, F1 Score=0.7823
# Epoch 221/2000 | Train: Loss=0.1198, F1 Score=0.9600 | Val: Loss=0.3779, F1 Score=0.7936
# Epoch 222/2000 | Train: Loss=0.1130, F1 Score=0.9663 | Val: Loss=0.4052, F1 Score=0.8058
# Epoch 223/2000 | Train: Loss=0.1078, F1 Score=0.9673 | Val: Loss=0.3762, F1 Score=0.8104
# Epoch 224/2000 | Train: Loss=0.1140, F1 Score=0.9654 | Val: Loss=0.3267, F1 Score=0.8435
# Epoch 225/2000 | Train: Loss=0.1073, F1 Score=0.9685 | Val: Loss=0.4785, F1 Score=0.7771
# Epoch 226/2000 | Train: Loss=0.1001, F1 Score=0.9729 | Val: Loss=0.3946, F1 Score=0.8112
# Epoch 227/2000 | Train: Loss=0.1112, F1 Score=0.9637 | Val: Loss=0.4209, F1 Score=0.8063
# Epoch 228/2000 | Train: Loss=0.1193, F1 Score=0.9620 | Val: Loss=0.4472, F1 Score=0.7964
# Epoch 229/2000 | Train: Loss=0.1161, F1 Score=0.9637 | Val: Loss=0.4802, F1 Score=0.7715
# Epoch 230/2000 | Train: Loss=0.1082, F1 Score=0.9710 | Val: Loss=0.4487, F1 Score=0.7966
# Epoch 231/2000 | Train: Loss=0.1084, F1 Score=0.9659 | Val: Loss=0.4669, F1 Score=0.7803
# Epoch 232/2000 | Train: Loss=0.1026, F1 Score=0.9718 | Val: Loss=0.4193, F1 Score=0.8087
# Epoch 233/2000 | Train: Loss=0.1080, F1 Score=0.9645 | Val: Loss=0.5421, F1 Score=0.7669
# Epoch 234/2000 | Train: Loss=0.1105, F1 Score=0.9665 | Val: Loss=0.3525, F1 Score=0.8264
# Epoch 235/2000 | Train: Loss=0.1067, F1 Score=0.9674 | Val: Loss=0.4551, F1 Score=0.7901
# Epoch 236/2000 | Train: Loss=0.1048, F1 Score=0.9682 | Val: Loss=0.4106, F1 Score=0.8078
# Epoch 237/2000 | Train: Loss=0.1009, F1 Score=0.9721 | Val: Loss=0.3877, F1 Score=0.8193
# Epoch 238/2000 | Train: Loss=0.1152, F1 Score=0.9624 | Val: Loss=0.4218, F1 Score=0.8101
# Epoch 239/2000 | Train: Loss=0.1044, F1 Score=0.9700 | Val: Loss=0.5488, F1 Score=0.7628
# Epoch 240/2000 | Train: Loss=0.1062, F1 Score=0.9671 | Val: Loss=0.3249, F1 Score=0.8452
# Epoch 241/2000 | Train: Loss=0.1105, F1 Score=0.9653 | Val: Loss=0.4006, F1 Score=0.8072
# Epoch 242/2000 | Train: Loss=0.1132, F1 Score=0.9666 | Val: Loss=0.4715, F1 Score=0.7955
# Epoch 243/2000 | Train: Loss=0.1037, F1 Score=0.9713 | Val: Loss=0.4393, F1 Score=0.7956
# Epoch 244/2000 | Train: Loss=0.1049, F1 Score=0.9690 | Val: Loss=0.3864, F1 Score=0.8117
# Epoch 245/2000 | Train: Loss=0.1119, F1 Score=0.9666 | Val: Loss=0.3971, F1 Score=0.8121
# Epoch 246/2000 | Train: Loss=0.1002, F1 Score=0.9729 | Val: Loss=0.4983, F1 Score=0.7777
# Epoch 247/2000 | Train: Loss=0.1024, F1 Score=0.9700 | Val: Loss=0.5711, F1 Score=0.7711
# Epoch 248/2000 | Train: Loss=0.1144, F1 Score=0.9644 | Val: Loss=0.4367, F1 Score=0.7854
# Epoch 249/2000 | Train: Loss=0.1020, F1 Score=0.9715 | Val: Loss=0.4667, F1 Score=0.7964
# Epoch 250/2000 | Train: Loss=0.1019, F1 Score=0.9700 | Val: Loss=0.5038, F1 Score=0.7845
# Epoch 251/2000 | Train: Loss=0.1109, F1 Score=0.9634 | Val: Loss=0.4284, F1 Score=0.8089
# Epoch 252/2000 | Train: Loss=0.1038, F1 Score=0.9710 | Val: Loss=0.3858, F1 Score=0.8106
# Epoch 253/2000 | Train: Loss=0.1010, F1 Score=0.9706 | Val: Loss=0.4251, F1 Score=0.8128
# Epoch 254/2000 | Train: Loss=0.0995, F1 Score=0.9712 | Val: Loss=0.4158, F1 Score=0.8015
# Epoch 255/2000 | Train: Loss=0.1026, F1 Score=0.9694 | Val: Loss=0.5172, F1 Score=0.8013
# Epoch 256/2000 | Train: Loss=0.1099, F1 Score=0.9623 | Val: Loss=0.4203, F1 Score=0.8112
# Epoch 257/2000 | Train: Loss=0.1029, F1 Score=0.9704 | Val: Loss=0.4782, F1 Score=0.7956
# Epoch 258/2000 | Train: Loss=0.0983, F1 Score=0.9720 | Val: Loss=0.3799, F1 Score=0.8263
# Epoch 259/2000 | Train: Loss=0.1078, F1 Score=0.9660 | Val: Loss=0.3673, F1 Score=0.8384
# Epoch 260/2000 | Train: Loss=0.1086, F1 Score=0.9686 | Val: Loss=0.4616, F1 Score=0.7859
# Epoch 261/2000 | Train: Loss=0.1043, F1 Score=0.9678 | Val: Loss=0.4173, F1 Score=0.8049
# Epoch 262/2000 | Train: Loss=0.1042, F1 Score=0.9682 | Val: Loss=0.3903, F1 Score=0.8179
# Epoch 263/2000 | Train: Loss=0.1087, F1 Score=0.9653 | Val: Loss=0.5038, F1 Score=0.7725
# Epoch 264/2000 | Train: Loss=0.1020, F1 Score=0.9725 | Val: Loss=0.3559, F1 Score=0.8440
# Epoch 265/2000 | Train: Loss=0.1026, F1 Score=0.9716 | Val: Loss=0.3693, F1 Score=0.8097
# Epoch 266/2000 | Train: Loss=0.0995, F1 Score=0.9717 | Val: Loss=0.4500, F1 Score=0.8160
# Epoch 267/2000 | Train: Loss=0.1031, F1 Score=0.9716 | Val: Loss=0.5124, F1 Score=0.7759
# Epoch 268/2000 | Train: Loss=0.1072, F1 Score=0.9664 | Val: Loss=0.4324, F1 Score=0.8207
# Epoch 269/2000 | Train: Loss=0.1009, F1 Score=0.9700 | Val: Loss=0.4618, F1 Score=0.8008
# Epoch 270/2000 | Train: Loss=0.0966, F1 Score=0.9747 | Val: Loss=0.5080, F1 Score=0.7839
# Epoch 271/2000 | Train: Loss=0.1013, F1 Score=0.9719 | Val: Loss=0.4560, F1 Score=0.8184
# Epoch 272/2000 | Train: Loss=0.1011, F1 Score=0.9724 | Val: Loss=0.4533, F1 Score=0.8075
# Epoch 273/2000 | Train: Loss=0.0963, F1 Score=0.9750 | Val: Loss=0.3953, F1 Score=0.8173
# Epoch 274/2000 | Train: Loss=0.1047, F1 Score=0.9681 | Val: Loss=0.3900, F1 Score=0.8163
# Epoch 275/2000 | Train: Loss=0.1001, F1 Score=0.9736 | Val: Loss=0.4115, F1 Score=0.8153
# Epoch 276/2000 | Train: Loss=0.0967, F1 Score=0.9734 | Val: Loss=0.4390, F1 Score=0.8091
# Epoch 277/2000 | Train: Loss=0.1052, F1 Score=0.9687 | Val: Loss=0.3732, F1 Score=0.8175
# Epoch 278/2000 | Train: Loss=0.0995, F1 Score=0.9710 | Val: Loss=0.4245, F1 Score=0.8189
# Epoch 279/2000 | Train: Loss=0.0962, F1 Score=0.9740 | Val: Loss=0.4551, F1 Score=0.8013
# Epoch 280/2000 | Train: Loss=0.0962, F1 Score=0.9733 | Val: Loss=0.4784, F1 Score=0.7906
# Epoch 281/2000 | Train: Loss=0.0956, F1 Score=0.9751 | Val: Loss=0.5272, F1 Score=0.7936
# Epoch 282/2000 | Train: Loss=0.1007, F1 Score=0.9711 | Val: Loss=0.4651, F1 Score=0.8151
# Epoch 283/2000 | Train: Loss=0.1113, F1 Score=0.9640 | Val: Loss=0.4569, F1 Score=0.7838
# Epoch 284/2000 | Train: Loss=0.0996, F1 Score=0.9739 | Val: Loss=0.4509, F1 Score=0.8114
# Epoch 285/2000 | Train: Loss=0.0944, F1 Score=0.9766 | Val: Loss=0.4598, F1 Score=0.8084
# Epoch 286/2000 | Train: Loss=0.0963, F1 Score=0.9737 | Val: Loss=0.4631, F1 Score=0.7909
# Epoch 287/2000 | Train: Loss=0.0980, F1 Score=0.9734 | Val: Loss=0.3531, F1 Score=0.8292
# Epoch 288/2000 | Train: Loss=0.0938, F1 Score=0.9759 | Val: Loss=0.4223, F1 Score=0.8248
# Epoch 289/2000 | Train: Loss=0.1018, F1 Score=0.9715 | Val: Loss=0.4625, F1 Score=0.7930
# Epoch 290/2000 | Train: Loss=0.1001, F1 Score=0.9725 | Val: Loss=0.4328, F1 Score=0.8207
# Epoch 291/2000 | Train: Loss=0.0974, F1 Score=0.9730 | Val: Loss=0.4284, F1 Score=0.8063
# Epoch 292/2000 | Train: Loss=0.0984, F1 Score=0.9723 | Val: Loss=0.4354, F1 Score=0.8006
# Epoch 293/2000 | Train: Loss=0.0918, F1 Score=0.9758 | Val: Loss=0.4497, F1 Score=0.8096
# Epoch 294/2000 | Train: Loss=0.1055, F1 Score=0.9690 | Val: Loss=0.3898, F1 Score=0.8333
# Epoch 295/2000 | Train: Loss=0.1055, F1 Score=0.9694 | Val: Loss=0.5261, F1 Score=0.7850
# Epoch 296/2000 | Train: Loss=0.1016, F1 Score=0.9706 | Val: Loss=0.3918, F1 Score=0.8196
# Epoch 297/2000 | Train: Loss=0.0925, F1 Score=0.9750 | Val: Loss=0.4531, F1 Score=0.8054
# Epoch 298/2000 | Train: Loss=0.1069, F1 Score=0.9681 | Val: Loss=0.3970, F1 Score=0.8063
# Epoch 299/2000 | Train: Loss=0.1020, F1 Score=0.9715 | Val: Loss=0.4653, F1 Score=0.7950
# Epoch 300/2000 | Train: Loss=0.0929, F1 Score=0.9763 | Val: Loss=0.4828, F1 Score=0.8058
# Epoch 301/2000 | Train: Loss=0.0949, F1 Score=0.9746 | Val: Loss=0.4614, F1 Score=0.7977
# Epoch 302/2000 | Train: Loss=0.0953, F1 Score=0.9741 | Val: Loss=0.5017, F1 Score=0.7972
# Epoch 303/2000 | Train: Loss=0.1025, F1 Score=0.9689 | Val: Loss=0.4111, F1 Score=0.8118
# Epoch 304/2000 | Train: Loss=0.0967, F1 Score=0.9742 | Val: Loss=0.5728, F1 Score=0.7755
# Epoch 305/2000 | Train: Loss=0.1027, F1 Score=0.9686 | Val: Loss=0.5753, F1 Score=0.7701
# Epoch 306/2000 | Train: Loss=0.1022, F1 Score=0.9710 | Val: Loss=0.4073, F1 Score=0.8089
# Epoch 307/2000 | Train: Loss=0.0985, F1 Score=0.9736 | Val: Loss=0.4607, F1 Score=0.8050
# Epoch 308/2000 | Train: Loss=0.0985, F1 Score=0.9729 | Val: Loss=0.5024, F1 Score=0.7998
# Epoch 309/2000 | Train: Loss=0.0948, F1 Score=0.9758 | Val: Loss=0.4190, F1 Score=0.8130
# Epoch 310/2000 | Train: Loss=0.0905, F1 Score=0.9779 | Val: Loss=0.4378, F1 Score=0.7969
# Epoch 311/2000 | Train: Loss=0.0974, F1 Score=0.9731 | Val: Loss=0.4895, F1 Score=0.7860
# Epoch 312/2000 | Train: Loss=0.0940, F1 Score=0.9747 | Val: Loss=0.4887, F1 Score=0.7977
# Epoch 313/2000 | Train: Loss=0.0959, F1 Score=0.9741 | Val: Loss=0.3806, F1 Score=0.8441
# Epoch 314/2000 | Train: Loss=0.1013, F1 Score=0.9724 | Val: Loss=0.4377, F1 Score=0.8140
# Epoch 315/2000 | Train: Loss=0.1037, F1 Score=0.9694 | Val: Loss=0.4001, F1 Score=0.8186
# Epoch 316/2000 | Train: Loss=0.0949, F1 Score=0.9758 | Val: Loss=0.4997, F1 Score=0.7995
# Epoch 317/2000 | Train: Loss=0.0875, F1 Score=0.9792 | Val: Loss=0.4819, F1 Score=0.8108
# Epoch 318/2000 | Train: Loss=0.0964, F1 Score=0.9723 | Val: Loss=0.5307, F1 Score=0.7802
# Epoch 319/2000 | Train: Loss=0.0919, F1 Score=0.9762 | Val: Loss=0.4773, F1 Score=0.8092
# Epoch 320/2000 | Train: Loss=0.1087, F1 Score=0.9630 | Val: Loss=0.4574, F1 Score=0.8054
# Epoch 321/2000 | Train: Loss=0.0947, F1 Score=0.9754 | Val: Loss=0.4789, F1 Score=0.7984
# Epoch 322/2000 | Train: Loss=0.0968, F1 Score=0.9744 | Val: Loss=0.3980, F1 Score=0.8255
# Epoch 323/2000 | Train: Loss=0.0948, F1 Score=0.9745 | Val: Loss=0.4403, F1 Score=0.8152
# Epoch 324/2000 | Train: Loss=0.0939, F1 Score=0.9744 | Val: Loss=0.4644, F1 Score=0.8122
# Epoch 325/2000 | Train: Loss=0.0882, F1 Score=0.9797 | Val: Loss=0.4027, F1 Score=0.8238
# Epoch 326/2000 | Train: Loss=0.0930, F1 Score=0.9770 | Val: Loss=0.4561, F1 Score=0.7977
# Epoch 327/2000 | Train: Loss=0.0996, F1 Score=0.9713 | Val: Loss=0.3797, F1 Score=0.8146
# Epoch 328/2000 | Train: Loss=0.0940, F1 Score=0.9758 | Val: Loss=0.4930, F1 Score=0.7957
# Epoch 329/2000 | Train: Loss=0.0909, F1 Score=0.9763 | Val: Loss=0.3629, F1 Score=0.8363
# Epoch 330/2000 | Train: Loss=0.0958, F1 Score=0.9725 | Val: Loss=0.5213, F1 Score=0.7818
# Epoch 331/2000 | Train: Loss=0.0981, F1 Score=0.9724 | Val: Loss=0.4998, F1 Score=0.7894
# Epoch 332/2000 | Train: Loss=0.0955, F1 Score=0.9730 | Val: Loss=0.4671, F1 Score=0.8060
# Epoch 333/2000 | Train: Loss=0.0968, F1 Score=0.9743 | Val: Loss=0.4955, F1 Score=0.7958
# Epoch 334/2000 | Train: Loss=0.0918, F1 Score=0.9777 | Val: Loss=0.4939, F1 Score=0.7903
# Epoch 335/2000 | Train: Loss=0.0948, F1 Score=0.9744 | Val: Loss=0.4331, F1 Score=0.8199
# Epoch 336/2000 | Train: Loss=0.1024, F1 Score=0.9696 | Val: Loss=0.5096, F1 Score=0.7824
# Epoch 337/2000 | Train: Loss=0.0949, F1 Score=0.9751 | Val: Loss=0.4734, F1 Score=0.8128
# Epoch 338/2000 | Train: Loss=0.0940, F1 Score=0.9739 | Val: Loss=0.4210, F1 Score=0.8159
# Epoch 339/2000 | Train: Loss=0.1131, F1 Score=0.9672 | Val: Loss=0.4376, F1 Score=0.8094
# Epoch 340/2000 | Train: Loss=0.0955, F1 Score=0.9755 | Val: Loss=0.5299, F1 Score=0.7869
# Epoch 341/2000 | Train: Loss=0.0893, F1 Score=0.9785 | Val: Loss=0.4898, F1 Score=0.7951
# Epoch 342/2000 | Train: Loss=0.0907, F1 Score=0.9774 | Val: Loss=0.4661, F1 Score=0.8088
# Epoch 343/2000 | Train: Loss=0.0914, F1 Score=0.9765 | Val: Loss=0.4965, F1 Score=0.7943
# Epoch 344/2000 | Train: Loss=0.0874, F1 Score=0.9782 | Val: Loss=0.4841, F1 Score=0.8050
# Epoch 345/2000 | Train: Loss=0.0900, F1 Score=0.9762 | Val: Loss=0.4628, F1 Score=0.8063
# Epoch 346/2000 | Train: Loss=0.1055, F1 Score=0.9693 | Val: Loss=0.6281, F1 Score=0.7613
# Epoch 347/2000 | Train: Loss=0.1003, F1 Score=0.9713 | Val: Loss=0.4407, F1 Score=0.8119
# Epoch 348/2000 | Train: Loss=0.0919, F1 Score=0.9754 | Val: Loss=0.4822, F1 Score=0.7948
# Epoch 349/2000 | Train: Loss=0.0984, F1 Score=0.9703 | Val: Loss=0.4583, F1 Score=0.8094
# Epoch 350/2000 | Train: Loss=0.0901, F1 Score=0.9762 | Val: Loss=0.4821, F1 Score=0.8084
# Epoch 351/2000 | Train: Loss=0.0895, F1 Score=0.9780 | Val: Loss=0.3937, F1 Score=0.8162
# Epoch 352/2000 | Train: Loss=0.0904, F1 Score=0.9773 | Val: Loss=0.3981, F1 Score=0.8181
# Epoch 353/2000 | Train: Loss=0.1023, F1 Score=0.9713 | Val: Loss=0.4645, F1 Score=0.7904
# Epoch 354/2000 | Train: Loss=0.0929, F1 Score=0.9758 | Val: Loss=0.4253, F1 Score=0.8044
# Epoch 355/2000 | Train: Loss=0.0905, F1 Score=0.9751 | Val: Loss=0.4405, F1 Score=0.8194
# Epoch 356/2000 | Train: Loss=0.0934, F1 Score=0.9730 | Val: Loss=0.4961, F1 Score=0.8010
# Epoch 357/2000 | Train: Loss=0.0910, F1 Score=0.9778 | Val: Loss=0.5095, F1 Score=0.8074
# Epoch 358/2000 | Train: Loss=0.0863, F1 Score=0.9787 | Val: Loss=0.5084, F1 Score=0.7951
# Epoch 359/2000 | Train: Loss=0.0890, F1 Score=0.9775 | Val: Loss=0.4840, F1 Score=0.7965
# Epoch 360/2000 | Train: Loss=0.0902, F1 Score=0.9767 | Val: Loss=0.4779, F1 Score=0.7942
# Epoch 361/2000 | Train: Loss=0.0908, F1 Score=0.9771 | Val: Loss=0.4258, F1 Score=0.8249
# Epoch 362/2000 | Train: Loss=0.0887, F1 Score=0.9779 | Val: Loss=0.5231, F1 Score=0.7985
# Epoch 363/2000 | Train: Loss=0.0893, F1 Score=0.9770 | Val: Loss=0.5075, F1 Score=0.7908
# Epoch 364/2000 | Train: Loss=0.0894, F1 Score=0.9763 | Val: Loss=0.4571, F1 Score=0.8150
# Epoch 365/2000 | Train: Loss=0.0967, F1 Score=0.9747 | Val: Loss=0.5156, F1 Score=0.8006
# Epoch 366/2000 | Train: Loss=0.0968, F1 Score=0.9719 | Val: Loss=0.4354, F1 Score=0.8154
# Epoch 367/2000 | Train: Loss=0.0911, F1 Score=0.9785 | Val: Loss=0.4347, F1 Score=0.8283
# Epoch 368/2000 | Train: Loss=0.0910, F1 Score=0.9764 | Val: Loss=0.4669, F1 Score=0.8000
# Epoch 369/2000 | Train: Loss=0.0941, F1 Score=0.9745 | Val: Loss=0.4670, F1 Score=0.7977
# Epoch 370/2000 | Train: Loss=0.1378, F1 Score=0.9564 | Val: Loss=0.4669, F1 Score=0.7881
# Epoch 371/2000 | Train: Loss=0.1001, F1 Score=0.9771 | Val: Loss=0.4832, F1 Score=0.7974
# Epoch 372/2000 | Train: Loss=0.0890, F1 Score=0.9801 | Val: Loss=0.5181, F1 Score=0.8014
# Epoch 373/2000 | Train: Loss=0.0961, F1 Score=0.9739 | Val: Loss=0.4906, F1 Score=0.8038
# Epoch 374/2000 | Train: Loss=0.0963, F1 Score=0.9739 | Val: Loss=0.5228, F1 Score=0.7913
# Epoch 375/2000 | Train: Loss=0.0903, F1 Score=0.9766 | Val: Loss=0.4965, F1 Score=0.8080
# Epoch 376/2000 | Train: Loss=0.0873, F1 Score=0.9781 | Val: Loss=0.4868, F1 Score=0.8082
# Epoch 377/2000 | Train: Loss=0.0838, F1 Score=0.9812 | Val: Loss=0.4847, F1 Score=0.8088
# Epoch 378/2000 | Train: Loss=0.0921, F1 Score=0.9749 | Val: Loss=0.5205, F1 Score=0.8020
# Epoch 379/2000 | Train: Loss=0.0946, F1 Score=0.9727 | Val: Loss=0.4661, F1 Score=0.8075
# Epoch 380/2000 | Train: Loss=0.0882, F1 Score=0.9782 | Val: Loss=0.4716, F1 Score=0.7967
# Epoch 381/2000 | Train: Loss=0.0851, F1 Score=0.9795 | Val: Loss=0.5025, F1 Score=0.7993
# Epoch 382/2000 | Train: Loss=0.0867, F1 Score=0.9815 | Val: Loss=0.5055, F1 Score=0.8070
# Epoch 383/2000 | Train: Loss=0.0899, F1 Score=0.9770 | Val: Loss=0.4995, F1 Score=0.7915
# Epoch 384/2000 | Train: Loss=0.0900, F1 Score=0.9772 | Val: Loss=0.5261, F1 Score=0.7909
# Epoch 385/2000 | Train: Loss=0.0864, F1 Score=0.9785 | Val: Loss=0.5093, F1 Score=0.7939
# Epoch 386/2000 | Train: Loss=0.1018, F1 Score=0.9694 | Val: Loss=0.4352, F1 Score=0.8039
# Epoch 387/2000 | Train: Loss=0.0935, F1 Score=0.9753 | Val: Loss=0.5064, F1 Score=0.7753
# Epoch 388/2000 | Train: Loss=0.0918, F1 Score=0.9770 | Val: Loss=0.4358, F1 Score=0.8156
# Epoch 389/2000 | Train: Loss=0.0872, F1 Score=0.9808 | Val: Loss=0.4484, F1 Score=0.8108
# Epoch 390/2000 | Train: Loss=0.0856, F1 Score=0.9783 | Val: Loss=0.4889, F1 Score=0.7991
# Epoch 391/2000 | Train: Loss=0.0947, F1 Score=0.9727 | Val: Loss=0.4762, F1 Score=0.8019
# Epoch 392/2000 | Train: Loss=0.0885, F1 Score=0.9762 | Val: Loss=0.4711, F1 Score=0.8119
# Epoch 393/2000 | Train: Loss=0.0913, F1 Score=0.9774 | Val: Loss=0.4877, F1 Score=0.8006
# Epoch 394/2000 | Train: Loss=0.0883, F1 Score=0.9799 | Val: Loss=0.4905, F1 Score=0.8084
# Epoch 395/2000 | Train: Loss=0.0889, F1 Score=0.9764 | Val: Loss=0.4902, F1 Score=0.7975
# Epoch 396/2000 | Train: Loss=0.0869, F1 Score=0.9781 | Val: Loss=0.4203, F1 Score=0.8285
# Epoch 397/2000 | Train: Loss=0.0858, F1 Score=0.9793 | Val: Loss=0.4736, F1 Score=0.7996
# Epoch 398/2000 | Train: Loss=0.0877, F1 Score=0.9782 | Val: Loss=0.5975, F1 Score=0.7665
# Epoch 399/2000 | Train: Loss=0.0944, F1 Score=0.9745 | Val: Loss=0.4711, F1 Score=0.7979
# Epoch 400/2000 | Train: Loss=0.0856, F1 Score=0.9815 | Val: Loss=0.4984, F1 Score=0.8048
# Epoch 401/2000 | Train: Loss=0.0874, F1 Score=0.9778 | Val: Loss=0.5249, F1 Score=0.7838
# Epoch 402/2000 | Train: Loss=0.0862, F1 Score=0.9778 | Val: Loss=0.4965, F1 Score=0.7959
# Epoch 403/2000 | Train: Loss=0.0944, F1 Score=0.9747 | Val: Loss=0.4852, F1 Score=0.7779
# Epoch 404/2000 | Train: Loss=0.0982, F1 Score=0.9733 | Val: Loss=0.3978, F1 Score=0.8194
# Epoch 405/2000 | Train: Loss=0.0903, F1 Score=0.9786 | Val: Loss=0.4959, F1 Score=0.7970
# Epoch 406/2000 | Train: Loss=0.0873, F1 Score=0.9790 | Val: Loss=0.4731, F1 Score=0.7992
# Epoch 407/2000 | Train: Loss=0.0842, F1 Score=0.9806 | Val: Loss=0.4983, F1 Score=0.7885
# Epoch 408/2000 | Train: Loss=0.0882, F1 Score=0.9788 | Val: Loss=0.4177, F1 Score=0.8238
# Epoch 409/2000 | Train: Loss=0.1014, F1 Score=0.9719 | Val: Loss=0.4870, F1 Score=0.8026
# Epoch 410/2000 | Train: Loss=0.0887, F1 Score=0.9794 | Val: Loss=0.5287, F1 Score=0.7821
# Epoch 411/2000 | Train: Loss=0.0844, F1 Score=0.9818 | Val: Loss=0.5598, F1 Score=0.7858
# Epoch 412/2000 | Train: Loss=0.0847, F1 Score=0.9818 | Val: Loss=0.4799, F1 Score=0.8049
# Epoch 413/2000 | Train: Loss=0.0872, F1 Score=0.9763 | Val: Loss=0.4615, F1 Score=0.8103
# Epoch 414/2000 | Train: Loss=0.0871, F1 Score=0.9785 | Val: Loss=0.6001, F1 Score=0.7691
# Epoch 415/2000 | Train: Loss=0.0990, F1 Score=0.9724 | Val: Loss=0.4785, F1 Score=0.7925
# Epoch 416/2000 | Train: Loss=0.0915, F1 Score=0.9771 | Val: Loss=0.5754, F1 Score=0.7781
# Epoch 417/2000 | Train: Loss=0.0863, F1 Score=0.9809 | Val: Loss=0.4055, F1 Score=0.8261
# Epoch 418/2000 | Train: Loss=0.0828, F1 Score=0.9798 | Val: Loss=0.5379, F1 Score=0.7912
# Epoch 419/2000 | Train: Loss=0.0883, F1 Score=0.9771 | Val: Loss=0.5785, F1 Score=0.7778
# Epoch 420/2000 | Train: Loss=0.0967, F1 Score=0.9762 | Val: Loss=0.5074, F1 Score=0.7875
# Epoch 421/2000 | Train: Loss=0.0947, F1 Score=0.9733 | Val: Loss=0.5153, F1 Score=0.7800
# Epoch 422/2000 | Train: Loss=0.0922, F1 Score=0.9788 | Val: Loss=0.4359, F1 Score=0.8126
# Epoch 423/2000 | Train: Loss=0.0862, F1 Score=0.9809 | Val: Loss=0.4765, F1 Score=0.8028
# Epoch 424/2000 | Train: Loss=0.0833, F1 Score=0.9807 | Val: Loss=0.5093, F1 Score=0.7776
# Epoch 425/2000 | Train: Loss=0.0867, F1 Score=0.9787 | Val: Loss=0.4726, F1 Score=0.8127
# Epoch 426/2000 | Train: Loss=0.0892, F1 Score=0.9755 | Val: Loss=0.4763, F1 Score=0.8017
# Epoch 427/2000 | Train: Loss=0.0864, F1 Score=0.9790 | Val: Loss=0.5000, F1 Score=0.7932
# Epoch 428/2000 | Train: Loss=0.0869, F1 Score=0.9790 | Val: Loss=0.4991, F1 Score=0.8088
# Epoch 429/2000 | Train: Loss=0.0976, F1 Score=0.9727 | Val: Loss=0.5297, F1 Score=0.7922
# Epoch 430/2000 | Train: Loss=0.0917, F1 Score=0.9786 | Val: Loss=0.5204, F1 Score=0.7933
# Epoch 431/2000 | Train: Loss=0.0917, F1 Score=0.9766 | Val: Loss=0.4757, F1 Score=0.7991
# Epoch 432/2000 | Train: Loss=0.0817, F1 Score=0.9818 | Val: Loss=0.5952, F1 Score=0.7700
# Epoch 433/2000 | Train: Loss=0.0884, F1 Score=0.9781 | Val: Loss=0.5028, F1 Score=0.7954
# Epoch 434/2000 | Train: Loss=0.0936, F1 Score=0.9737 | Val: Loss=0.4564, F1 Score=0.7972
# Epoch 435/2000 | Train: Loss=0.0882, F1 Score=0.9765 | Val: Loss=0.4525, F1 Score=0.8187
# Epoch 436/2000 | Train: Loss=0.0827, F1 Score=0.9813 | Val: Loss=0.4562, F1 Score=0.8133
# Epoch 437/2000 | Train: Loss=0.0806, F1 Score=0.9810 | Val: Loss=0.4965, F1 Score=0.8037
# Epoch 438/2000 | Train: Loss=0.0818, F1 Score=0.9820 | Val: Loss=0.5262, F1 Score=0.7969
# Epoch 439/2000 | Train: Loss=0.0851, F1 Score=0.9808 | Val: Loss=0.5058, F1 Score=0.7963
# Epoch 440/2000 | Train: Loss=0.0837, F1 Score=0.9820 | Val: Loss=0.4428, F1 Score=0.8067
# Epoch 441/2000 | Train: Loss=0.0874, F1 Score=0.9799 | Val: Loss=0.5109, F1 Score=0.7574
# Epoch 442/2000 | Train: Loss=0.0972, F1 Score=0.9739 | Val: Loss=0.5066, F1 Score=0.7912
# Epoch 443/2000 | Train: Loss=0.0924, F1 Score=0.9795 | Val: Loss=0.4767, F1 Score=0.8092
# Epoch 444/2000 | Train: Loss=0.0820, F1 Score=0.9833 | Val: Loss=0.5543, F1 Score=0.7703
# Epoch 445/2000 | Train: Loss=0.0880, F1 Score=0.9785 | Val: Loss=0.5095, F1 Score=0.7890
# Epoch 446/2000 | Train: Loss=0.0806, F1 Score=0.9827 | Val: Loss=0.4837, F1 Score=0.8108
# Epoch 447/2000 | Train: Loss=0.0861, F1 Score=0.9774 | Val: Loss=0.5404, F1 Score=0.7988
# Epoch 448/2000 | Train: Loss=0.0879, F1 Score=0.9772 | Val: Loss=0.5726, F1 Score=0.7743
# Epoch 449/2000 | Train: Loss=0.1014, F1 Score=0.9688 | Val: Loss=0.4395, F1 Score=0.8101
# Epoch 450/2000 | Train: Loss=0.0907, F1 Score=0.9772 | Val: Loss=0.4426, F1 Score=0.8129
# Epoch 451/2000 | Train: Loss=0.0899, F1 Score=0.9770 | Val: Loss=0.4605, F1 Score=0.8062
# Epoch 452/2000 | Train: Loss=0.0803, F1 Score=0.9841 | Val: Loss=0.4127, F1 Score=0.8201
# Epoch 453/2000 | Train: Loss=0.0802, F1 Score=0.9828 | Val: Loss=0.4917, F1 Score=0.7956
# Epoch 454/2000 | Train: Loss=0.0842, F1 Score=0.9802 | Val: Loss=0.5818, F1 Score=0.7689
# Epoch 455/2000 | Train: Loss=0.0895, F1 Score=0.9770 | Val: Loss=0.5242, F1 Score=0.7831
# Epoch 456/2000 | Train: Loss=0.0850, F1 Score=0.9809 | Val: Loss=0.4874, F1 Score=0.7962
# Epoch 457/2000 | Train: Loss=0.0812, F1 Score=0.9830 | Val: Loss=0.4758, F1 Score=0.7939
# Epoch 458/2000 | Train: Loss=0.0789, F1 Score=0.9836 | Val: Loss=0.4864, F1 Score=0.8029
# Epoch 459/2000 | Train: Loss=0.0807, F1 Score=0.9832 | Val: Loss=0.5181, F1 Score=0.8063
# Epoch 460/2000 | Train: Loss=0.0808, F1 Score=0.9804 | Val: Loss=0.5132, F1 Score=0.7944
# Epoch 461/2000 | Train: Loss=0.0984, F1 Score=0.9730 | Val: Loss=0.4896, F1 Score=0.7889
# Epoch 462/2000 | Train: Loss=0.0941, F1 Score=0.9787 | Val: Loss=0.4122, F1 Score=0.8389
# Epoch 463/2000 | Train: Loss=0.0866, F1 Score=0.9809 | Val: Loss=0.4717, F1 Score=0.8091
# Epoch 464/2000 | Train: Loss=0.0838, F1 Score=0.9828 | Val: Loss=0.4165, F1 Score=0.8200
# Epoch 465/2000 | Train: Loss=0.0913, F1 Score=0.9751 | Val: Loss=0.4315, F1 Score=0.8209
# Epoch 466/2000 | Train: Loss=0.0876, F1 Score=0.9759 | Val: Loss=0.5840, F1 Score=0.7734
# Epoch 467/2000 | Train: Loss=0.0848, F1 Score=0.9797 | Val: Loss=0.5011, F1 Score=0.7876
# Epoch 468/2000 | Train: Loss=0.0854, F1 Score=0.9786 | Val: Loss=0.5102, F1 Score=0.7971
# Epoch 469/2000 | Train: Loss=0.0808, F1 Score=0.9833 | Val: Loss=0.5012, F1 Score=0.7970
# Epoch 470/2000 | Train: Loss=0.0807, F1 Score=0.9833 | Val: Loss=0.5037, F1 Score=0.8073
# Epoch 471/2000 | Train: Loss=0.0769, F1 Score=0.9844 | Val: Loss=0.5638, F1 Score=0.7889
# Epoch 472/2000 | Train: Loss=0.0864, F1 Score=0.9798 | Val: Loss=0.4533, F1 Score=0.8086
# Epoch 473/2000 | Train: Loss=0.0848, F1 Score=0.9799 | Val: Loss=0.5121, F1 Score=0.7821
# Epoch 474/2000 | Train: Loss=0.0808, F1 Score=0.9833 | Val: Loss=0.5918, F1 Score=0.7735
# Epoch 475/2000 | Train: Loss=0.0821, F1 Score=0.9816 | Val: Loss=0.4450, F1 Score=0.8139
# Epoch 476/2000 | Train: Loss=0.0818, F1 Score=0.9808 | Val: Loss=0.4916, F1 Score=0.8033
# Epoch 477/2000 | Train: Loss=0.0917, F1 Score=0.9745 | Val: Loss=0.4933, F1 Score=0.7938
# Epoch 478/2000 | Train: Loss=0.0921, F1 Score=0.9777 | Val: Loss=0.4677, F1 Score=0.8018
# Epoch 479/2000 | Train: Loss=0.0806, F1 Score=0.9826 | Val: Loss=0.4691, F1 Score=0.8014
# Epoch 480/2000 | Train: Loss=0.0913, F1 Score=0.9769 | Val: Loss=0.4395, F1 Score=0.8036
# Epoch 481/2000 | Train: Loss=0.0876, F1 Score=0.9805 | Val: Loss=0.5671, F1 Score=0.7720
# Epoch 482/2000 | Train: Loss=0.0892, F1 Score=0.9776 | Val: Loss=0.5137, F1 Score=0.7853
# Epoch 483/2000 | Train: Loss=0.0787, F1 Score=0.9848 | Val: Loss=0.4824, F1 Score=0.8094
# Epoch 484/2000 | Train: Loss=0.0925, F1 Score=0.9750 | Val: Loss=0.4350, F1 Score=0.8194
# Epoch 485/2000 | Train: Loss=0.0788, F1 Score=0.9851 | Val: Loss=0.4923, F1 Score=0.8119
# Epoch 486/2000 | Train: Loss=0.0819, F1 Score=0.9801 | Val: Loss=0.5111, F1 Score=0.8027
# Epoch 487/2000 | Train: Loss=0.0780, F1 Score=0.9847 | Val: Loss=0.5470, F1 Score=0.7864
# Epoch 488/2000 | Train: Loss=0.0825, F1 Score=0.9809 | Val: Loss=0.5335, F1 Score=0.7759
# Epoch 489/2000 | Train: Loss=0.0938, F1 Score=0.9742 | Val: Loss=0.4840, F1 Score=0.7881
# Epoch 490/2000 | Train: Loss=0.0823, F1 Score=0.9836 | Val: Loss=0.5258, F1 Score=0.7952
# Epoch 491/2000 | Train: Loss=0.0795, F1 Score=0.9825 | Val: Loss=0.5274, F1 Score=0.7909
# Epoch 492/2000 | Train: Loss=0.0781, F1 Score=0.9847 | Val: Loss=0.5022, F1 Score=0.7844
# Epoch 493/2000 | Train: Loss=0.0857, F1 Score=0.9782 | Val: Loss=0.6744, F1 Score=0.7488
# Epoch 494/2000 | Train: Loss=0.0865, F1 Score=0.9777 | Val: Loss=0.4842, F1 Score=0.7927
# Epoch 495/2000 | Train: Loss=0.0873, F1 Score=0.9781 | Val: Loss=0.5467, F1 Score=0.7816
# Epoch 496/2000 | Train: Loss=0.0876, F1 Score=0.9776 | Val: Loss=0.4733, F1 Score=0.8061
# Epoch 497/2000 | Train: Loss=0.0782, F1 Score=0.9844 | Val: Loss=0.4970, F1 Score=0.7984
# Epoch 498/2000 | Train: Loss=0.0810, F1 Score=0.9805 | Val: Loss=0.5306, F1 Score=0.7936
# Epoch 499/2000 | Train: Loss=0.0831, F1 Score=0.9794 | Val: Loss=0.5574, F1 Score=0.7784
# Epoch 500/2000 | Train: Loss=0.0761, F1 Score=0.9865 | Val: Loss=0.6178, F1 Score=0.7691
# Epoch 501/2000 | Train: Loss=0.0795, F1 Score=0.9823 | Val: Loss=0.5150, F1 Score=0.7931
# Epoch 502/2000 | Train: Loss=0.0867, F1 Score=0.9762 | Val: Loss=0.5643, F1 Score=0.7744
# Epoch 503/2000 | Train: Loss=0.0874, F1 Score=0.9801 | Val: Loss=0.4685, F1 Score=0.8125
# Epoch 504/2000 | Train: Loss=0.0816, F1 Score=0.9827 | Val: Loss=0.4953, F1 Score=0.8058
# Epoch 505/2000 | Train: Loss=0.0785, F1 Score=0.9836 | Val: Loss=0.5644, F1 Score=0.7827
# Epoch 506/2000 | Train: Loss=0.0878, F1 Score=0.9753 | Val: Loss=0.5294, F1 Score=0.7862
# Epoch 507/2000 | Train: Loss=0.0838, F1 Score=0.9802 | Val: Loss=0.5336, F1 Score=0.8008
# Epoch 508/2000 | Train: Loss=0.0903, F1 Score=0.9773 | Val: Loss=0.5417, F1 Score=0.7758
# Epoch 509/2000 | Train: Loss=0.0881, F1 Score=0.9804 | Val: Loss=0.5115, F1 Score=0.7810
# Epoch 510/2000 | Train: Loss=0.0837, F1 Score=0.9819 | Val: Loss=0.5585, F1 Score=0.7709
# Epoch 511/2000 | Train: Loss=0.0797, F1 Score=0.9845 | Val: Loss=0.6027, F1 Score=0.7771
# Epoch 512/2000 | Train: Loss=0.0825, F1 Score=0.9810 | Val: Loss=0.5688, F1 Score=0.7849
# Epoch 513/2000 | Train: Loss=0.0761, F1 Score=0.9839 | Val: Loss=0.5246, F1 Score=0.7815
# Epoch 514/2000 | Train: Loss=0.0754, F1 Score=0.9850 | Val: Loss=0.5310, F1 Score=0.7822
# Epoch 515/2000 | Train: Loss=0.0745, F1 Score=0.9861 | Val: Loss=0.5268, F1 Score=0.8058
# Epoch 516/2000 | Train: Loss=0.0782, F1 Score=0.9838 | Val: Loss=0.5523, F1 Score=0.7928
# Epoch 517/2000 | Train: Loss=0.0893, F1 Score=0.9755 | Val: Loss=0.5819, F1 Score=0.7571
# Epoch 518/2000 | Train: Loss=0.0787, F1 Score=0.9828 | Val: Loss=0.5266, F1 Score=0.7954
# Epoch 519/2000 | Train: Loss=0.0926, F1 Score=0.9752 | Val: Loss=0.6038, F1 Score=0.7591
# Epoch 520/2000 | Train: Loss=0.1049, F1 Score=0.9728 | Val: Loss=0.4680, F1 Score=0.8097
# Epoch 521/2000 | Train: Loss=0.0796, F1 Score=0.9846 | Val: Loss=0.5723, F1 Score=0.7809
# Epoch 522/2000 | Train: Loss=0.0920, F1 Score=0.9747 | Val: Loss=0.5658, F1 Score=0.7671
# Epoch 523/2000 | Train: Loss=0.0822, F1 Score=0.9811 | Val: Loss=0.4335, F1 Score=0.8051
# Epoch 524/2000 | Train: Loss=0.0838, F1 Score=0.9815 | Val: Loss=0.5328, F1 Score=0.7899
# Epoch 525/2000 | Train: Loss=0.0762, F1 Score=0.9847 | Val: Loss=0.4936, F1 Score=0.8079
# Epoch 526/2000 | Train: Loss=0.0773, F1 Score=0.9835 | Val: Loss=0.5002, F1 Score=0.8005
# Epoch 527/2000 | Train: Loss=0.0792, F1 Score=0.9826 | Val: Loss=0.5070, F1 Score=0.8095
# Epoch 528/2000 | Train: Loss=0.0770, F1 Score=0.9818 | Val: Loss=0.6215, F1 Score=0.7724
# Epoch 529/2000 | Train: Loss=0.0788, F1 Score=0.9812 | Val: Loss=0.5470, F1 Score=0.7922
# Epoch 530/2000 | Train: Loss=0.0808, F1 Score=0.9826 | Val: Loss=0.5193, F1 Score=0.7918
# Epoch 531/2000 | Train: Loss=0.0778, F1 Score=0.9856 | Val: Loss=0.4861, F1 Score=0.7889
# Epoch 532/2000 | Train: Loss=0.0837, F1 Score=0.9788 | Val: Loss=0.5583, F1 Score=0.7844
# Epoch 533/2000 | Train: Loss=0.0950, F1 Score=0.9765 | Val: Loss=0.4694, F1 Score=0.7991
# Epoch 534/2000 | Train: Loss=0.0840, F1 Score=0.9811 | Val: Loss=0.4570, F1 Score=0.8091
# Epoch 535/2000 | Train: Loss=0.0818, F1 Score=0.9821 | Val: Loss=0.4824, F1 Score=0.7988
# Epoch 536/2000 | Train: Loss=0.0800, F1 Score=0.9825 | Val: Loss=0.4788, F1 Score=0.8040
# Epoch 537/2000 | Train: Loss=0.0757, F1 Score=0.9869 | Val: Loss=0.4185, F1 Score=0.8333
# Epoch 538/2000 | Train: Loss=0.0889, F1 Score=0.9783 | Val: Loss=0.5361, F1 Score=0.7860
# Epoch 539/2000 | Train: Loss=0.0767, F1 Score=0.9846 | Val: Loss=0.4469, F1 Score=0.8219
# ...
# Epoch 564/2000 | Train: Loss=0.0765, F1 Score=0.9854 | Val: Loss=0.5276, F1 Score=0.7874
# Epoch 565/2000 | Train: Loss=0.0761, F1 Score=0.9834 | Val: Loss=0.4686, F1 Score=0.8114
# Epoch 566/2000 | Train: Loss=0.0738, F1 Score=0.9851 | Val: Loss=0.5454, F1 Score=0.7944
# Epoch 567/2000 | Train: Loss=0.0759, F1 Score=0.9828 | Val: Loss=0.5633, F1 Score=0.7841
# Epoch 568/2000 | Train: Loss=0.0807, F1 Score=0.9801 | Val: Loss=0.5239, F1 Score=0.8037
# Epoch 569/2000 | Train: Loss=0.0832, F1 Score=0.9781 | Val: Loss=0.5243, F1 Score=0.7928
# Epoch 570/2000 | Train: Loss=0.0773, F1 Score=0.9839 | Val: Loss=0.5020, F1 Score=0.7927
# Epoch 571/2000 | Train: Loss=0.0904, F1 Score=0.9773 | Val: Loss=0.5702, F1 Score=0.7959
# Epoch 572/2000 | Train: Loss=0.0938, F1 Score=0.9766 | Val: Loss=0.5055, F1 Score=0.7945
# Epoch 573/2000 | Train: Loss=0.0761, F1 Score=0.9862 | Val: Loss=0.5877, F1 Score=0.7638
# Epoch 574/2000 | Train: Loss=0.0808, F1 Score=0.9804 | Val: Loss=0.4895, F1 Score=0.8026
# Epoch 575/2000 | Train: Loss=0.0795, F1 Score=0.9825 | Val: Loss=0.5045, F1 Score=0.8054
# Epoch 576/2000 | Train: Loss=0.0750, F1 Score=0.9859 | Val: Loss=0.5426, F1 Score=0.7950
# Epoch 577/2000 | Train: Loss=0.0781, F1 Score=0.9823 | Val: Loss=0.5660, F1 Score=0.7792
# Epoch 578/2000 | Train: Loss=0.0881, F1 Score=0.9785 | Val: Loss=0.5468, F1 Score=0.7952
# Epoch 579/2000 | Train: Loss=0.0873, F1 Score=0.9780 | Val: Loss=0.5205, F1 Score=0.7917
# Epoch 580/2000 | Train: Loss=0.0821, F1 Score=0.9818 | Val: Loss=0.5311, F1 Score=0.7934
# Epoch 581/2000 | Train: Loss=0.0753, F1 Score=0.9866 | Val: Loss=0.5109, F1 Score=0.7984
# Epoch 582/2000 | Train: Loss=0.0728, F1 Score=0.9873 | Val: Loss=0.4890, F1 Score=0.8071
# Epoch 583/2000 | Train: Loss=0.0933, F1 Score=0.9742 | Val: Loss=0.4925, F1 Score=0.7956
# Epoch 584/2000 | Train: Loss=0.0906, F1 Score=0.9805 | Val: Loss=0.5012, F1 Score=0.8018
# Epoch 585/2000 | Train: Loss=0.0858, F1 Score=0.9809 | Val: Loss=0.5100, F1 Score=0.7878
# Epoch 586/2000 | Train: Loss=0.0853, F1 Score=0.9812 | Val: Loss=0.5075, F1 Score=0.7999
# Epoch 587/2000 | Train: Loss=0.0789, F1 Score=0.9809 | Val: Loss=0.4870, F1 Score=0.7917
# Epoch 588/2000 | Train: Loss=0.0796, F1 Score=0.9821 | Val: Loss=0.6380, F1 Score=0.7745
# Epoch 589/2000 | Train: Loss=0.0823, F1 Score=0.9830 | Val: Loss=0.5591, F1 Score=0.7913
# Epoch 590/2000 | Train: Loss=0.0782, F1 Score=0.9844 | Val: Loss=0.5491, F1 Score=0.7941
# Epoch 591/2000 | Train: Loss=0.0818, F1 Score=0.9791 | Val: Loss=0.5109, F1 Score=0.7931
# Epoch 592/2000 | Train: Loss=0.0849, F1 Score=0.9787 | Val: Loss=0.5493, F1 Score=0.7785
# Epoch 593/2000 | Train: Loss=0.0778, F1 Score=0.9828 | Val: Loss=0.5600, F1 Score=0.7799
# Epoch 594/2000 | Train: Loss=0.0790, F1 Score=0.9822 | Val: Loss=0.5641, F1 Score=0.7954
# Epoch 595/2000 | Train: Loss=0.0904, F1 Score=0.9760 | Val: Loss=0.5672, F1 Score=0.7684
# Epoch 596/2000 | Train: Loss=0.0884, F1 Score=0.9775 | Val: Loss=0.4920, F1 Score=0.7913
# Epoch 597/2000 | Train: Loss=0.0738, F1 Score=0.9867 | Val: Loss=0.4858, F1 Score=0.8204
# Epoch 598/2000 | Train: Loss=0.0777, F1 Score=0.9840 | Val: Loss=0.4775, F1 Score=0.7956
# Epoch 599/2000 | Train: Loss=0.0799, F1 Score=0.9830 | Val: Loss=0.5899, F1 Score=0.7794
# Epoch 600/2000 | Train: Loss=0.0805, F1 Score=0.9824 | Val: Loss=0.4680, F1 Score=0.8076
# Epoch 601/2000 | Train: Loss=0.0731, F1 Score=0.9859 | Val: Loss=0.4904, F1 Score=0.8001
# Epoch 602/2000 | Train: Loss=0.0749, F1 Score=0.9834 | Val: Loss=0.4643, F1 Score=0.8070
# Epoch 603/2000 | Train: Loss=0.0739, F1 Score=0.9861 | Val: Loss=0.5542, F1 Score=0.7998
# Epoch 604/2000 | Train: Loss=0.0773, F1 Score=0.9817 | Val: Loss=0.5095, F1 Score=0.7914
# Epoch 605/2000 | Train: Loss=0.0822, F1 Score=0.9773 | Val: Loss=0.6362, F1 Score=0.7578
# Epoch 606/2000 | Train: Loss=0.0788, F1 Score=0.9832 | Val: Loss=0.5018, F1 Score=0.8137
# Epoch 607/2000 | Train: Loss=0.0743, F1 Score=0.9853 | Val: Loss=0.4957, F1 Score=0.8197
# Epoch 608/2000 | Train: Loss=0.0801, F1 Score=0.9825 | Val: Loss=0.6113, F1 Score=0.7641
# Epoch 609/2000 | Train: Loss=0.0809, F1 Score=0.9811 | Val: Loss=0.5258, F1 Score=0.7961
# Epoch 610/2000 | Train: Loss=0.0921, F1 Score=0.9735 | Val: Loss=0.5188, F1 Score=0.7908
# Epoch 611/2000 | Train: Loss=0.0769, F1 Score=0.9871 | Val: Loss=0.4561, F1 Score=0.8213
# Epoch 612/2000 | Train: Loss=0.0840, F1 Score=0.9807 | Val: Loss=0.5783, F1 Score=0.7803
# Epoch 613/2000 | Train: Loss=0.0893, F1 Score=0.9759 | Val: Loss=0.5536, F1 Score=0.7787
# Epoch 614/2000 | Train: Loss=0.0736, F1 Score=0.9872 | Val: Loss=0.4658, F1 Score=0.8136
# Epoch 615/2000 | Train: Loss=0.0763, F1 Score=0.9846 | Val: Loss=0.5974, F1 Score=0.7765
# Epoch 616/2000 | Train: Loss=0.0813, F1 Score=0.9801 | Val: Loss=0.5123, F1 Score=0.8105
# Epoch 617/2000 | Train: Loss=0.0788, F1 Score=0.9828 | Val: Loss=0.5323, F1 Score=0.7966
# Epoch 618/2000 | Train: Loss=0.0771, F1 Score=0.9846 | Val: Loss=0.5143, F1 Score=0.8117
# Epoch 619/2000 | Train: Loss=0.0737, F1 Score=0.9858 | Val: Loss=0.5607, F1 Score=0.7924
# Epoch 620/2000 | Train: Loss=0.0834, F1 Score=0.9790 | Val: Loss=0.4855, F1 Score=0.7984
# Epoch 621/2000 | Train: Loss=0.0853, F1 Score=0.9800 | Val: Loss=0.5697, F1 Score=0.7713
# Epoch 622/2000 | Train: Loss=0.0787, F1 Score=0.9812 | Val: Loss=0.5175, F1 Score=0.7916
# Epoch 623/2000 | Train: Loss=0.0754, F1 Score=0.9835 | Val: Loss=0.4811, F1 Score=0.8121
# Epoch 624/2000 | Train: Loss=0.0951, F1 Score=0.9739 | Val: Loss=0.4829, F1 Score=0.8010
# Epoch 625/2000 | Train: Loss=0.0753, F1 Score=0.9862 | Val: Loss=0.4887, F1 Score=0.8125
# Epoch 626/2000 | Train: Loss=0.0787, F1 Score=0.9820 | Val: Loss=0.5568, F1 Score=0.7981
# Epoch 627/2000 | Train: Loss=0.0974, F1 Score=0.9721 | Val: Loss=0.4896, F1 Score=0.7862
# Epoch 628/2000 | Train: Loss=0.0802, F1 Score=0.9825 | Val: Loss=0.5251, F1 Score=0.7939
# Epoch 629/2000 | Train: Loss=0.0827, F1 Score=0.9806 | Val: Loss=0.4691, F1 Score=0.8138
# Epoch 630/2000 | Train: Loss=0.0727, F1 Score=0.9864 | Val: Loss=0.5555, F1 Score=0.7791
# Epoch 631/2000 | Train: Loss=0.0736, F1 Score=0.9854 | Val: Loss=0.5905, F1 Score=0.7769
# Epoch 632/2000 | Train: Loss=0.0783, F1 Score=0.9837 | Val: Loss=0.5293, F1 Score=0.8076
# Epoch 633/2000 | Train: Loss=0.0856, F1 Score=0.9776 | Val: Loss=0.4695, F1 Score=0.7983
# Epoch 634/2000 | Train: Loss=0.0789, F1 Score=0.9831 | Val: Loss=0.5162, F1 Score=0.7964
# Epoch 635/2000 | Train: Loss=0.0761, F1 Score=0.9837 | Val: Loss=0.4981, F1 Score=0.8134
# Epoch 636/2000 | Train: Loss=0.0781, F1 Score=0.9822 | Val: Loss=0.4819, F1 Score=0.7932
# Epoch 637/2000 | Train: Loss=0.0823, F1 Score=0.9812 | Val: Loss=0.5334, F1 Score=0.7952
# Epoch 638/2000 | Train: Loss=0.0722, F1 Score=0.9872 | Val: Loss=0.5122, F1 Score=0.7884
# Epoch 639/2000 | Train: Loss=0.0816, F1 Score=0.9813 | Val: Loss=0.5511, F1 Score=0.8013
# Epoch 640/2000 | Train: Loss=0.0775, F1 Score=0.9829 | Val: Loss=0.4895, F1 Score=0.8047
# Epoch 641/2000 | Train: Loss=0.0768, F1 Score=0.9836 | Val: Loss=0.5110, F1 Score=0.7932
# Epoch 642/2000 | Train: Loss=0.0706, F1 Score=0.9876 | Val: Loss=0.5465, F1 Score=0.8128
# Epoch 643/2000 | Train: Loss=0.0731, F1 Score=0.9850 | Val: Loss=0.5229, F1 Score=0.8007
# Epoch 644/2000 | Train: Loss=0.0738, F1 Score=0.9853 | Val: Loss=0.5169, F1 Score=0.8048
# Epoch 645/2000 | Train: Loss=0.0843, F1 Score=0.9785 | Val: Loss=0.4743, F1 Score=0.8024
# Epoch 646/2000 | Train: Loss=0.0847, F1 Score=0.9794 | Val: Loss=0.4616, F1 Score=0.8036
# Epoch 647/2000 | Train: Loss=0.0838, F1 Score=0.9823 | Val: Loss=0.5055, F1 Score=0.7995
# Epoch 648/2000 | Train: Loss=0.0732, F1 Score=0.9872 | Val: Loss=0.5077, F1 Score=0.7981
# Epoch 649/2000 | Train: Loss=0.0698, F1 Score=0.9888 | Val: Loss=0.5403, F1 Score=0.7785
# Epoch 650/2000 | Train: Loss=0.0759, F1 Score=0.9822 | Val: Loss=0.5846, F1 Score=0.7589
# Epoch 651/2000 | Train: Loss=0.0784, F1 Score=0.9828 | Val: Loss=0.5581, F1 Score=0.7676
# Epoch 652/2000 | Train: Loss=0.0754, F1 Score=0.9842 | Val: Loss=0.5048, F1 Score=0.7948
# Epoch 653/2000 | Train: Loss=0.0773, F1 Score=0.9838 | Val: Loss=0.6133, F1 Score=0.7573
# Epoch 654/2000 | Train: Loss=0.0880, F1 Score=0.9778 | Val: Loss=0.5178, F1 Score=0.8008
# Epoch 655/2000 | Train: Loss=0.0822, F1 Score=0.9813 | Val: Loss=0.5871, F1 Score=0.7441
# Epoch 656/2000 | Train: Loss=0.0872, F1 Score=0.9789 | Val: Loss=0.4948, F1 Score=0.7976
# Epoch 657/2000 | Train: Loss=0.0785, F1 Score=0.9849 | Val: Loss=0.4592, F1 Score=0.8179
# Epoch 658/2000 | Train: Loss=0.0700, F1 Score=0.9890 | Val: Loss=0.4752, F1 Score=0.8173
# Epoch 659/2000 | Train: Loss=0.0741, F1 Score=0.9850 | Val: Loss=0.4679, F1 Score=0.8100
# Epoch 660/2000 | Train: Loss=0.0841, F1 Score=0.9802 | Val: Loss=0.4119, F1 Score=0.8137
# Epoch 661/2000 | Train: Loss=0.0932, F1 Score=0.9805 | Val: Loss=0.4929, F1 Score=0.7946
# Epoch 662/2000 | Train: Loss=0.0939, F1 Score=0.9751 | Val: Loss=0.4616, F1 Score=0.8223
# Epoch 663/2000 | Train: Loss=0.0857, F1 Score=0.9804 | Val: Loss=0.4879, F1 Score=0.7828
# Epoch 664/2000 | Train: Loss=0.0747, F1 Score=0.9862 | Val: Loss=0.5265, F1 Score=0.7944
# Epoch 665/2000 | Train: Loss=0.0697, F1 Score=0.9883 | Val: Loss=0.5132, F1 Score=0.8074
# Epoch 666/2000 | Train: Loss=0.0743, F1 Score=0.9850 | Val: Loss=0.5193, F1 Score=0.7935
# Epoch 667/2000 | Train: Loss=0.0776, F1 Score=0.9830 | Val: Loss=0.4913, F1 Score=0.8115
# Epoch 668/2000 | Train: Loss=0.0709, F1 Score=0.9882 | Val: Loss=0.5132, F1 Score=0.8022
# Epoch 669/2000 | Train: Loss=0.0811, F1 Score=0.9806 | Val: Loss=0.6079, F1 Score=0.7781
# Epoch 670/2000 | Train: Loss=0.0805, F1 Score=0.9807 | Val: Loss=0.5253, F1 Score=0.7772
# Epoch 671/2000 | Train: Loss=0.0759, F1 Score=0.9841 | Val: Loss=0.4898, F1 Score=0.7983
# Epoch 672/2000 | Train: Loss=0.0748, F1 Score=0.9850 | Val: Loss=0.5070, F1 Score=0.7869
# Epoch 673/2000 | Train: Loss=0.0719, F1 Score=0.9874 | Val: Loss=0.5570, F1 Score=0.8088
# Epoch 674/2000 | Train: Loss=0.0748, F1 Score=0.9827 | Val: Loss=0.5347, F1 Score=0.8009
# Epoch 675/2000 | Train: Loss=0.0841, F1 Score=0.9825 | Val: Loss=0.5194, F1 Score=0.7976
# Epoch 676/2000 | Train: Loss=0.0776, F1 Score=0.9831 | Val: Loss=0.5394, F1 Score=0.7885
# Epoch 677/2000 | Train: Loss=0.0759, F1 Score=0.9813 | Val: Loss=0.5311, F1 Score=0.7808
# Epoch 678/2000 | Train: Loss=0.0714, F1 Score=0.9874 | Val: Loss=0.5788, F1 Score=0.7989
# Epoch 679/2000 | Train: Loss=0.0827, F1 Score=0.9820 | Val: Loss=0.4978, F1 Score=0.8043
# Epoch 680/2000 | Train: Loss=0.0750, F1 Score=0.9862 | Val: Loss=0.4491, F1 Score=0.8081
# Epoch 681/2000 | Train: Loss=0.0748, F1 Score=0.9845 | Val: Loss=0.4874, F1 Score=0.8047
# Epoch 682/2000 | Train: Loss=0.0733, F1 Score=0.9850 | Val: Loss=0.5372, F1 Score=0.8036
# Epoch 683/2000 | Train: Loss=0.0866, F1 Score=0.9790 | Val: Loss=0.5243, F1 Score=0.7940
# Epoch 684/2000 | Train: Loss=0.0771, F1 Score=0.9848 | Val: Loss=0.4363, F1 Score=0.8231
# Epoch 685/2000 | Train: Loss=0.0832, F1 Score=0.9814 | Val: Loss=0.5132, F1 Score=0.7827
# Epoch 686/2000 | Train: Loss=0.0767, F1 Score=0.9846 | Val: Loss=0.5019, F1 Score=0.8128
# Epoch 687/2000 | Train: Loss=0.0757, F1 Score=0.9836 | Val: Loss=0.5376, F1 Score=0.7821
# Epoch 688/2000 | Train: Loss=0.0754, F1 Score=0.9849 | Val: Loss=0.5309, F1 Score=0.8127
# Epoch 689/2000 | Train: Loss=0.0769, F1 Score=0.9859 | Val: Loss=0.5369, F1 Score=0.7862
# Epoch 690/2000 | Train: Loss=0.0741, F1 Score=0.9844 | Val: Loss=0.5376, F1 Score=0.7956
# Epoch 691/2000 | Train: Loss=0.0826, F1 Score=0.9809 | Val: Loss=0.5171, F1 Score=0.8057
# Epoch 692/2000 | Train: Loss=0.0921, F1 Score=0.9785 | Val: Loss=0.4983, F1 Score=0.8172
# Epoch 693/2000 | Train: Loss=0.0767, F1 Score=0.9862 | Val: Loss=0.4897, F1 Score=0.8025
# Epoch 694/2000 | Train: Loss=0.0809, F1 Score=0.9821 | Val: Loss=0.4591, F1 Score=0.8221
# Epoch 695/2000 | Train: Loss=0.0744, F1 Score=0.9859 | Val: Loss=0.5812, F1 Score=0.7724
# Epoch 696/2000 | Train: Loss=0.0747, F1 Score=0.9849 | Val: Loss=0.5149, F1 Score=0.7980
# Epoch 697/2000 | Train: Loss=0.0735, F1 Score=0.9866 | Val: Loss=0.5418, F1 Score=0.8066
# Epoch 698/2000 | Train: Loss=0.0774, F1 Score=0.9830 | Val: Loss=0.5433, F1 Score=0.8014
# Epoch 699/2000 | Train: Loss=0.0740, F1 Score=0.9854 | Val: Loss=0.5743, F1 Score=0.7936
# Epoch 700/2000 | Train: Loss=0.0726, F1 Score=0.9861 | Val: Loss=0.5025, F1 Score=0.8052
# Epoch 701/2000 | Train: Loss=0.0700, F1 Score=0.9885 | Val: Loss=0.5109, F1 Score=0.8023
# Epoch 702/2000 | Train: Loss=0.0706, F1 Score=0.9882 | Val: Loss=0.5557, F1 Score=0.8081
# Epoch 703/2000 | Train: Loss=0.0801, F1 Score=0.9825 | Val: Loss=0.4973, F1 Score=0.8094
# Epoch 704/2000 | Train: Loss=0.0827, F1 Score=0.9799 | Val: Loss=0.4932, F1 Score=0.8173
# Epoch 705/2000 | Train: Loss=0.0852, F1 Score=0.9801 | Val: Loss=0.4557, F1 Score=0.8104
# Epoch 706/2000 | Train: Loss=0.0782, F1 Score=0.9838 | Val: Loss=0.6685, F1 Score=0.7545
# Epoch 707/2000 | Train: Loss=0.0746, F1 Score=0.9845 | Val: Loss=0.5312, F1 Score=0.8122
# Epoch 708/2000 | Train: Loss=0.0787, F1 Score=0.9819 | Val: Loss=0.5363, F1 Score=0.7924
# Epoch 709/2000 | Train: Loss=0.0752, F1 Score=0.9854 | Val: Loss=0.5667, F1 Score=0.7726
# Epoch 710/2000 | Train: Loss=0.0899, F1 Score=0.9758 | Val: Loss=0.4580, F1 Score=0.8103
# Epoch 711/2000 | Train: Loss=0.0801, F1 Score=0.9825 | Val: Loss=0.4908, F1 Score=0.8011
# Epoch 712/2000 | Train: Loss=0.0726, F1 Score=0.9884 | Val: Loss=0.5023, F1 Score=0.8066
# Epoch 713/2000 | Train: Loss=0.0703, F1 Score=0.9874 | Val: Loss=0.5715, F1 Score=0.7866
# Epoch 714/2000 | Train: Loss=0.0713, F1 Score=0.9859 | Val: Loss=0.5222, F1 Score=0.7891
# Epoch 715/2000 | Train: Loss=0.0711, F1 Score=0.9868 | Val: Loss=0.5050, F1 Score=0.8108
# Epoch 716/2000 | Train: Loss=0.0775, F1 Score=0.9830 | Val: Loss=0.5013, F1 Score=0.8029
# Epoch 717/2000 | Train: Loss=0.0720, F1 Score=0.9858 | Val: Loss=0.5475, F1 Score=0.7877
# Epoch 718/2000 | Train: Loss=0.0970, F1 Score=0.9730 | Val: Loss=0.4724, F1 Score=0.7993
# Epoch 719/2000 | Train: Loss=0.0825, F1 Score=0.9818 | Val: Loss=0.5130, F1 Score=0.8007
# Epoch 720/2000 | Train: Loss=0.0732, F1 Score=0.9881 | Val: Loss=0.4623, F1 Score=0.8090
# Epoch 721/2000 | Train: Loss=0.0748, F1 Score=0.9850 | Val: Loss=0.5260, F1 Score=0.7962
# Epoch 722/2000 | Train: Loss=0.0792, F1 Score=0.9821 | Val: Loss=0.5383, F1 Score=0.7956
# Epoch 723/2000 | Train: Loss=0.0825, F1 Score=0.9781 | Val: Loss=0.5167, F1 Score=0.7982
# Epoch 724/2000 | Train: Loss=0.0705, F1 Score=0.9881 | Val: Loss=0.5565, F1 Score=0.7904
# Epoch 725/2000 | Train: Loss=0.0718, F1 Score=0.9869 | Val: Loss=0.5505, F1 Score=0.8053
# Epoch 726/2000 | Train: Loss=0.0685, F1 Score=0.9890 | Val: Loss=0.5333, F1 Score=0.7961
# Epoch 727/2000 | Train: Loss=0.0694, F1 Score=0.9890 | Val: Loss=0.5829, F1 Score=0.7830
# Epoch 728/2000 | Train: Loss=0.0710, F1 Score=0.9863 | Val: Loss=0.5979, F1 Score=0.7716
# Epoch 729/2000 | Train: Loss=0.0755, F1 Score=0.9836 | Val: Loss=0.5318, F1 Score=0.7867
# Epoch 730/2000 | Train: Loss=0.0865, F1 Score=0.9775 | Val: Loss=0.5014, F1 Score=0.8033
# Epoch 731/2000 | Train: Loss=0.0767, F1 Score=0.9837 | Val: Loss=0.5126, F1 Score=0.8002
# Epoch 732/2000 | Train: Loss=0.0732, F1 Score=0.9872 | Val: Loss=0.6377, F1 Score=0.7788
# Epoch 733/2000 | Train: Loss=0.0775, F1 Score=0.9804 | Val: Loss=0.4984, F1 Score=0.8031
# Epoch 734/2000 | Train: Loss=0.0722, F1 Score=0.9872 | Val: Loss=0.5157, F1 Score=0.7945
# Epoch 735/2000 | Train: Loss=0.0777, F1 Score=0.9824 | Val: Loss=0.5668, F1 Score=0.7794
# Epoch 736/2000 | Train: Loss=0.0788, F1 Score=0.9835 | Val: Loss=0.5240, F1 Score=0.7956
# Epoch 737/2000 | Train: Loss=0.0741, F1 Score=0.9856 | Val: Loss=0.5911, F1 Score=0.7869
# Epoch 738/2000 | Train: Loss=0.0733, F1 Score=0.9858 | Val: Loss=0.6071, F1 Score=0.7837
# Epoch 739/2000 | Train: Loss=0.0788, F1 Score=0.9823 | Val: Loss=0.4910, F1 Score=0.8150
# Epoch 740/2000 | Train: Loss=0.0770, F1 Score=0.9849 | Val: Loss=0.6239, F1 Score=0.7770
# Early stopping triggered after 740 epochs.
# Best model restored from epoch 240 with val_f1 0.8452
# CPU times: user 53min 28s, sys: 1min 58s, total: 55min 27s
# Wall time: 55min 49s

# %%
# @title Train Hitory
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
# @title Confusion Matrix
# Collect predictions and ground truth labels
val_preds, val_targets = [], []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in val_loader:
        xb = xb.to(device)

        # Forward pass: get model predictions
        logits = model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average=f1_average)
val_rec = recall_score(val_targets, val_preds, average=f1_average)
val_f1 = f1_score(val_targets, val_preds, average=f1_average)
print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualise confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='',
            cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.9248
# Precision over the validation set: 0.8671
# Recall over the validation set: 0.8271
# F1 score over the validation set: 0.8457

# %% [markdown]
# # Test

# %%
def build_test_sequences(df, features, window=200, stride=200):
    """
    Builds sequences for inference from the test set.
    This version does not handle labels but tracks sample indices.
    """
    assert window % stride == 0
    dataset = []
    sample_indices = []

    # Iterate over unique sample IDs in the DataFrame
    for id in df['sample_index'].unique():
        # Extract sensor data for the current ID
        temp = df[df['sample_index'] == id][features].values

        # Calculate padding length to ensure full windows
        padding_len = (window - len(temp) % window) % window

        # Create zero padding and concatenate with the data if needed
        if padding_len > 0:
            padding = np.zeros((padding_len, len(features)), dtype='float64')
            temp = np.concatenate((temp, padding))

        # Build feature windows and associate them with their original sample_index
        idx = 0
        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            sample_indices.append(id)
            idx += stride

    # Convert lists to numpy arrays for further processing
    dataset = np.array(dataset)

    return dataset, sample_indices

# %%
# Instantiate model for test
inference_model = AttentionClassifier(
    input_size=input_shape[-1], # Pass the number of features
    hidden_size=HIDDEN_SIZE,
    num_layers=HIDDEN_LAYERS,
    num_classes=3,
    dropout_rate=DROPOUT_RATE,
).to(device)

model_name = experiment_name
model_path = "models/" + model_name + "_model.pt"
inference_model.load_state_dict(torch.load(model_path, map_location=device)) # Load the best model saved on file after training

inference_model.eval()

print("Model loaded successfully and set to evaluation mode.")
# Out:
# Model loaded successfully and set to evaluation mode.

# %%
# 1. Build sequences from the preprocessed test data
# Use the same window and stride as in training for consistency.
test_x_seq, test_sample_indices = build_test_sequences(
    X_test,
    features,
    window=WINDOW_SIZE,
    stride=STRIDE
)

print(f"Created {len(test_x_seq)} sequences from the test set.")

# 2. Create a TensorDataset and DataLoader for the test set
# The dataset only contains the input sequences (no labels).
test_ds = TensorDataset(torch.from_numpy(test_x_seq).float())

test_loader = make_loader(test_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
# Out:
# Created 35748 sequences from the test set.

# %%
all_predictions = []

# 1. Run inference on the test set
print("Running inference on test data...")
with torch.no_grad():
    for (inputs,) in test_loader:  # Note the comma to unpack the single-item tuple
        inputs = inputs.to(device)

        # Forward pass
        logits = inference_model(inputs)

        # Get predictions (the class with the highest logit)
        predictions = logits.argmax(dim=1).cpu().numpy()
        all_predictions.extend(predictions)

print("Inference complete.")

# 2. Aggregate predictions for each sample_index
# We have multiple predictions per sample, so we take the most common one (mode).
df_preds = pd.DataFrame({
    'sample_index': test_sample_indices,
    'prediction': all_predictions
})

# Group by sample_index and find the most frequent prediction
final_preds = df_preds.groupby('sample_index')['prediction'].apply(lambda x: x.mode()[0]).reset_index()

print("Predictions aggregated by sample_index.")
# Out:
# Running inference on test data...
# Inference complete.
# Predictions aggregated by sample_index.

# %%
# 1. Convert numeric predictions back to original string labels
final_preds['label'] = label_encoder.inverse_transform(final_preds['prediction'])

# 2. Create the final submission DataFrame with the required columns
submission_df = final_preds[['sample_index', 'label']]

# 3. Save the DataFrame to a CSV file
submission_path = current_dir + '/submissions/submission_' + model_name + '.csv'
submission_df.to_csv(submission_path, index=False)

print(f"Submission file saved to '{submission_path}'")
print("\nFirst 5 rows of the submission file:")
print(submission_df.head())
# Out:
# Submission file saved to '/gdrive/My Drive/ANN-1stChallenge/submissions/submission_final_nomid_2.csv'
#
# First 5 rows of the submission file:
#    sample_index      label
# 0             0  high_pain
# 1             1    no_pain
# 2             2    no_pain
# 3             3    no_pain
# 4             4    no_pain

# %%
# @title Plot test prediction distribution
n_np = len(submission_df[submission_df['label'] == 'no_pain'])
n_lp = len(submission_df[submission_df['label'] == 'low_pain'])
n_hp = len(submission_df[submission_df['label'] == 'high_pain'])

# Data for plotting
labels = ['no_pain', 'low_pain', 'high_pain']
counts = [n_np, n_lp, n_hp]

# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(labels, counts, color=['skyblue', 'salmon', 'lightgreen'])

# Add titles and labels for clarity
plt.title('Distribution of Predicted Labels in Test Set')
plt.xlabel('Pain Level')
plt.ylabel('Number of Samples')

# Add the count numbers on top of each bar
for i, count in enumerate(counts):
    plt.text(i, count + 10, str(count), ha='center', fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
